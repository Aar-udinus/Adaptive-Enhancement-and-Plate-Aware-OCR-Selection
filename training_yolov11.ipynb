# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40  Python-3.10.19 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (16 CPUs, 15.7 GB RAM, 389.4/952.9 GB disk)

# %%
# !pip install ultralytics supervision "ultralytics<=8.3.40"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6LNEkt1gffqmwr1GOY2M")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov11")
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained model (e.g., yolov11n.pt)
model = YOLO('yolo11n.pt')

# Train the model on your custom dataset
# The 'data' parameter refers to the YAML file provided by Roboflow
results = model.train(data='C:\\projek_jurnal\\License-Plate-Recognition-11\\data.yaml', epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.10.19 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
Image(filename=f'/runs/detect/train/confusion_matrix.png', width=800)
