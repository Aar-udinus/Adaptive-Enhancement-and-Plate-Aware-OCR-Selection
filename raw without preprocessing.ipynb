# %%
import os

# Kurangi konflik OpenMP/MKL
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

# Sering membantu kalau ada error libomp duplicate
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %% [markdown]
# #PaddeOCR Crop From Yolov11#

# %%
import os
import csv
import re
import cv2
from paddleocr import PaddleOCR

# ============================================================
# 0) CONFIG
# ============================================================
INPUT_FOLDER = r"D:\Uniska\~Disertasi\~Projek Jurnal\sr_crop-RJ"  # <-- ganti
OUT_CSV      = r"Result_Crop_Yolov11.csv"          # <-- ganti

# ============================================================
# 1) OCR INIT
# ============================================================
ocr = PaddleOCR(
    use_angle_cls=True,
    lang='en',
    show_log=False,
    det_db_thresh=0.3
)

# ============================================================
# 2) BASIC HELPERS
# ============================================================
def clean_raw(text: str) -> str:
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def pick_best_line(result):
    
    if result is None:
        return "", 0.0
    if not isinstance(result, list) or len(result) == 0:
        return "", 0.0

    # kasus umum: result = [ [line1, line2, ...] ]
    lines = result[0] if (len(result) == 1 and isinstance(result[0], list)) else result
    if lines is None:
        return "", 0.0

    best_text, best_conf = "", 0.0
    for line in lines:
        try:
            txt = line[1][0]
            conf = float(line[1][1])
        except Exception:
            continue
        if conf > best_conf and txt:
            best_text, best_conf = str(txt), conf
    return best_text, best_conf

# ============================================================
# 3) VARIANTS (TANPA CLAHE & TANPA SR2x)
# ============================================================
def make_variants(img):
    # Hanya RAW (no preprocessing)
    return [("RAW", img)]
    # Jika mau pembanding ringan tapi tetap tanpa CLAHE/SR:
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # return [("RAW", img), ("GRAY", gray)]

# ============================================================
# 4) NORMALIZATION (RJ fixed position)
# ============================================================
def normalize_rj_fixedpos_with_meta(raw_text: str):
    """
    Normalisasi plat format fixed-length=10:
      [0]=R, [1]=J, [2-3]=digit, [4-5]=alpha, [6-9]=digit
    Return: final_plate (str), casts (int), anchor_bonus (float)
    """
    t0 = clean_raw(raw_text)

    # 1) Anchor RJ
    anchor_bonus = 0.0
    if "RJ" in t0:
        anchor_bonus = 0.15
        t = t0[t0.find("RJ"):]
    else:
        t = "RJ" + t0

    # 2) Enforce length 10
    if len(t) < 10:
        t = t.ljust(10, "0")
    else:
        t = t[:10]

    chars = list(t)

    # Hard prefix
    chars[0], chars[1] = "R", "J"

    # 3) Casting berbasis posisi
    digit_idx = {2, 3, 6, 7, 8, 9}
    alpha_idx = {4, 5}

    to_digit = {
        "O": "0", "Q": "0", "D": "0",
        "I": "1", "L": "1",
        "Z": "2",
        "S": "5",
        "B": "8",
    }
    to_alpha = {"0": "O", "1": "I", "2": "Z", "5": "S", "8": "B"}

    casts = 0

    for i in range(10):
        c = chars[i]

        if i in digit_idx and c in to_digit:
            newc = to_digit[c]
            if newc != c:
                chars[i] = newc
                casts += 1

        elif i in alpha_idx and c in to_alpha:
            newc = to_alpha[c]
            if newc != c:
                chars[i] = newc
                casts += 1

    # 4) Rule khusus pasangan ambiguitas pada posisi [4-5]
    #    Mendukung: OC, CO, 0C, C0  -> Target QC / CQ
    pair = chars[4] + chars[5]
    pair_map = {
        "OC": ("Q", "C"),
        "CO": ("C", "Q"),
        "0C": ("Q", "C"),
        "C0": ("C", "Q"),
    }
    if pair in pair_map:
        new4, new5 = pair_map[pair]
        if (chars[4], chars[5]) != (new4, new5):
            chars[4], chars[5] = new4, new5
            casts += 1

    final_plate = "".join(chars)
    return final_plate, casts, anchor_bonus

def struct_score_rj(plate10: str) -> float:
    if not plate10 or len(plate10) != 10:
        return 0.0
    c = list(plate10)
    ok = 0
    ok += 1 if c[0] == "R" else 0
    ok += 1 if c[1] == "J" else 0
    for i in [2, 3, 6, 7, 8, 9]:
        ok += 1 if c[i].isdigit() else 0
    for i in [4, 5]:
        ok += 1 if c[i].isalpha() else 0
    return ok / 10.0

# ============================================================
# 5) QC/CQ AMBIGUITY FIX WITH GATE (FIXED INDENTATION)
# ============================================================
def apply_qc_gate(plate10: str, raw_text: str, other_candidates_have_qpair: bool):
    """
    Fix:
      OC -> QC
      CO -> CQ
      0C -> QC
      C0 -> CQ
    ONLY if evidence (gate):
      - raw OCR text contains 'Q' anywhere, OR
      - another variant produced QC/CQ explicitly
    Return: (new_plate, add_cast)
    """
    if not plate10 or len(plate10) != 10:
        return plate10, 0

    chars = list(plate10)
    pair = chars[4] + chars[5]
    if pair not in ("OC", "CO", "0C", "C0"):
        return plate10, 0

    t = clean_raw(raw_text)
    gate_raw_has_q = ("Q" in t)
    gate_other = bool(other_candidates_have_qpair)

    if not (gate_raw_has_q or gate_other):
        return plate10, 0

    if pair == "OC":
        chars[4], chars[5] = "Q", "C"
        return "".join(chars), 1
    if pair == "CO":
        chars[4], chars[5] = "C", "Q"
        return "".join(chars), 1
    if pair == "0C":
        chars[4], chars[5] = "Q", "C"
        return "".join(chars), 1
    if pair == "C0":
        chars[4], chars[5] = "C", "Q"
        return "".join(chars), 1

    return plate10, 0

# ============================================================
# 6) PLATE-AWARE SCORING
# ============================================================
def score_candidate(conf, struct_score, casts, anchor_bonus):
    w_conf = 0.55
    w_struct = 0.45
    cast_penalty = min(casts, 6) * 0.02  # max 0.12
    return (w_conf * float(conf)) + (w_struct * float(struct_score)) + float(anchor_bonus) - cast_penalty

def select_best_across_variants(variant_results):
    """
    variant_results: list of (variant_name, paddle_result)
    Return dict best or None
    """
    # gate evidence: apakah ada kandidat yang eksplisit menghasilkan QC/CQ di raw OCR?
    other_has_qpair = False
    for vname, pres in variant_results:
        raw_text, conf = pick_best_line(pres)
        if not raw_text:
            continue
        t = clean_raw(raw_text)
        if ("QC" in t) or ("CQ" in t):
            other_has_qpair = True
            break

    best = None
    for vname, pres in variant_results:
        raw_text, conf = pick_best_line(pres)
        if not raw_text:
            continue

        final_plate, casts, anchor_bonus = normalize_rj_fixedpos_with_meta(raw_text)

        # apply gated ambiguity fix
        final_plate2, add_cast = apply_qc_gate(final_plate, raw_text, other_has_qpair)
        casts += add_cast
        final_plate = final_plate2

        s_struct = struct_score_rj(final_plate)
        s_total = score_candidate(conf, s_struct, casts, anchor_bonus)

        cand = {
            "variant": vname,
            "raw_text": raw_text,
            "final_plate": final_plate,
            "conf": float(conf),
            "score_total": float(s_total),
            "casts": int(casts),
            "struct_score": float(s_struct),
            "anchor_bonus": float(anchor_bonus),
        }

        if (best is None) or (cand["score_total"] > best["score_total"]):
            best = cand

    return best

# ============================================================
# 7) MAIN LOOP -> CSV
# ============================================================
image_files = sorted([
    f for f in os.listdir(INPUT_FOLDER)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
])

with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow([
        "File_Name","Variant","Raw_OCR","Final_Plate",
        "Conf_0to1","Score","Casts","StructScore","AnchorBonus"
    ])

    for fn in image_files:
        img_path = os.path.join(INPUT_FOLDER, fn)
        img = cv2.imread(img_path)

        if img is None:
            w.writerow([fn,"","","",0,0,0,0,0])
            print("BAD IMAGE:", fn)
            continue

        variant_results = []
        for vname, vimg in make_variants(img):
            try:
                pres = ocr.ocr(vimg, cls=True)
            except Exception:
                pres = None
            variant_results.append((vname, pres))

        best = select_best_across_variants(variant_results)

        if best is None:
            w.writerow([fn,"","","",0,0,0,0,0])
            print("NO TEXT:", fn)
        else:
            w.writerow([
                fn,
                best["variant"],
                best["raw_text"],
                best["final_plate"],
                round(best["conf"], 6),
                round(best["score_total"], 6),
                best["casts"],
                round(best["struct_score"], 6),
                round(best["anchor_bonus"], 6)
            ])
            print(f"OK: {fn} | {best['variant']} | {best['raw_text']} → {best['final_plate']}")

print("DONE. Saved:", OUT_CSV)
# Out:
# OK: 100.png | RAW | RJ45CK4748 → RJ45CK4748
# OK: 1000.png | RAW | RJ14CG-6581 → RJ14CG6581
# OK: 1001.png | RAW | FRJ14CK8305 → RJ14CK8305
# OK: 101.png | RAW | RJ14CZ0391 → RJ14CZ0391
# OK: 102.png | RAW | RJ45CH4583 → RJ45CH4583
# OK: 103.png | RAW | FRJ45CJ9969 → RJ45CJ9969
# OK: 104.png | RAW | RJ14LC6763 → RJ14LC6763
# OK: 105.png | RAW | RJ31CF7171 → RJ31CF7171
# OK: 106.png | RAW | -RJ08CA6767 → RJ08CA6767
# OK: 107.png | RAW | RJ45CH9693 → RJ45CH9693
# OK: 108.png | RAW | RJ45CK7827 → RJ45CK7827
# OK: 109.png | RAW | RJ45CQ1702 → RJ45CQ1702
# OK: 111.png | RAW | RJ14CF 9928 → RJ14CF9928
# OK: 112.png | RAW | -RJ45CQ9137 → RJ45CQ9137
# OK: 113.png | RAW | RS14CY6039 → RJR5I4CY60
# OK: 114.png | RAW | RJ14 CG 9094 → RJ14CG9094
# OK: 115.png | RAW | FRJ14VC0628 → RJ14VC0628
# OK: 116.png | RAW | RJ14CD 4810 → RJ14CD4810
# OK: 118.png | RAW | RJ14XC6909 → RJ14XC6909
# NO TEXT: 119.png
# OK: 120.png | RAW | RJ45CN2934 → RJ45CN2934
# OK: 122.png | RAW | FRJ45C00611 → RJ45CQ0611
# OK: 123.png | RAW | FRJ14079165 → RJ14O79165
# NO TEXT: 124.png
# OK: 125.png | RAW | RJ45CV3753 → RJ45CV3753
# OK: 126.png | RAW | PRJ140C9780 → RJ14QC9780
# OK: 389.png | RAW | RJ23UB 6081 → RJ23UB6081
# OK: 390.png | RAW | RJ02CC6621 → RJ02CC6621
# OK: 391.png | RAW | -RJ21UG0044 → RJ21UG0044
# OK: 392.png | RAW | RJ14UF1632 → RJ14UF1632
# OK: 393.png | RAW | "RJ45CT9496 → RJ45CT9496
# OK: 394.png | RAW | RJ18 CD2193 → RJ18CD2193
# OK: 395.png | RAW | RJ02 CC 4642 → RJ02CC4642
# OK: 396.png | RAW | RJ14UG8209 → RJ14UG8209
# OK: 397.png | RAW | ~RJ45CP5704 → RJ45CP5704
# OK: 398.png | RAW | RJ45CA2953 → RJ45CA2953
# OK: 399.png | RAW | RJ45CR2576 → RJ45CR2576
# OK: 400.png | RAW | RJ13CB6214 → RJ13CB6214
# OK: 401.png | RAW | RJM4 CL 1162 → RJM4CL1162
# OK: 402.png | RAW | RJ14 ZC 2864 → RJ14ZC2864
# OK: 403.png | RAW | RJ14CU5325 → RJ14CU5325
# OK: 404.png | RAW | RJ14UH7046 → RJ14UH7046
# OK: 405.png | RAW | RJ14TD0733 → RJ14TD0733
# OK: 406.png | RAW | RJ45CS0617 → RJ45CS0617
# OK: 407.png | RAW | RJ14TB4095 → RJ14TB4095
# OK: 408.png | RAW | RJ45CT6689 → RJ45CT6689
# OK: 409.png | RAW | RJ14TB1265 → RJ14TB1265
# OK: 410.png | RAW | RJ14TB7738 → RJ14TB7738
# OK: 411.png | RAW | RJ14TD0908 → RJ14TD0908
# OK: 412.png | RAW | PRJ14TD4148 → RJ14TD4148
# OK: 413.png | RAW | RJ14UD8337 → RJ14UD8337
# OK: 414.png | RAW | RJ06UA9743 → RJ06UA9743
# OK: 415.png | RAW | FRJ14TD7268 → RJ14TD7268
# OK: 416.png | RAW | RJ47TA0568 → RJ47TA0568
# OK: 417.png | RAW | RJ14TB7210 → RJ14TB7210
# OK: 418.png | RAW | RJ18CD3382 → RJ18CD3382
# OK: 419.png | RAW | RJ23UA4493 → RJ23UA4493
# OK: 420.png | RAW | RJ14UH4591 → RJ14UH4591
# OK: 421.png | RAW | RJ14TB9315 → RJ14TB9315
# OK: 423.png | RAW | RJ22UB1551 → RJ22UB1551
# OK: 425.png | RAW | "RJ45CT3790 → RJ45CT3790
# OK: 426.png | RAW | "RJ45CT1885 → RJ45CT1885
# OK: 427.png | RAW | "RJ45CT3790 → RJ45CT3790
# OK: 428.png | RAW | RJ07CD5141 → RJ07CD5141
# OK: 429.png | RAW | RJ45CE2714 → RJ45CE2714
# OK: 430.png | RAW | RJ06CC2305 → RJ06CC2305
# OK: 434.png | RAW | RJ14 CA9656 → RJ14CA9656
# OK: 435.png | RAW | RJ14VC5878 → RJ14VC5878
# OK: 436.png | RAW | RJ14 CN 2137 → RJ14CN2137
# OK: 437.png | RAW | RJ45CU8299 → RJ45CU8299
# OK: 438.png | RAW | RJ14CT8400 → RJ14CT8400
# OK: 440.png | RAW | RJ14WC6764 → RJ14WC6764
# OK: 441.png | RAW | RJ14NC3343 → RJ14NC3343
# OK: 848.png | RAW | FRJ45C07703 → RJ45CQ7703
# OK: 849.png | RAW | RJ45CS4737 → RJ45CS4737
# OK: 85.png | RAW | RJ45CL4748 → RJ45CL4748
# OK: 850.png | RAW | RJ45CV1494 → RJ45CV1494
# OK: 851.png | RAW | RJ14CX3188 → RJ14CX3188
# OK: 852.png | RAW | RJ14CC0979 → RJ14CC0979
# OK: 853.png | RAW | -RJ45CP6364 → RJ45CP6364
# OK: 854.png | RAW | FRJ14WC1303 → RJ14WC1303
# OK: 856.png | RAW | RJ45CP8366 → RJ45CP8366
# OK: 857.png | RAW | RJ14CQ3372 → RJ14CQ3372
# OK: 858.png | RAW | [RJ147C0010] → RJ147C0010
# OK: 859.png | RAW | RJ14CT7262 → RJ14CT7262
# OK: 86.png | RAW | RJ45CM6898 → RJ45CM6898
# OK: 861.png | RAW | RJ14TE0516 → RJ14TE0516
# OK: 862.png | RAW | RJ45CU1237 → RJ45CU1237
# OK: 863.png | RAW | RJ29CA5938 → RJ29CA5938
# OK: 864.png | RAW | RJ14CE3763 → RJ14CE3763
# OK: 865.png | RAW | RJ14CZ6795 → RJ14CZ6795
# OK: 866.png | RAW | RJ14UH0270 → RJ14UH0270
# OK: 867.png | RAW | RJ45CH1213 → RJ45CH1213
# OK: 868.png | RAW | RJ45CU1897 → RJ45CU1897
# OK: 869.png | RAW | RJ29CA7848 → RJ29CA7848
# OK: 87.png | RAW | RJ45CU3690 → RJ45CU3690
# OK: 870.png | RAW | RJ45CV0109 → RJ45CV0109
# OK: 871.png | RAW | RJ14CC8393] → RJ14CC8393
# NO TEXT: 872.png
# OK: 873.png | RAW | RJ14TD0741 → RJ14TD0741
# OK: 874.png | RAW | RJ14CY5022 → RJ14CY5022
# OK: 875.png | RAW | RJ14CB6100 → RJ14CB6100
# OK: 876.png | RAW | RJ21 CB 3598 → RJ21CB3598
# OK: 877.png | RAW | RJ45CE3482 → RJ45CE3482
# OK: 878.png | RAW | RJ14UJ0992 → RJ14UJ0992
# OK: 879.png | RAW | FRJ08CA6767 → RJ08CA6767
# OK: 88.png | RAW | RJ45CL4097 → RJ45CL4097
# OK: 880.png | RAW | -RJ45CN9693 → RJ45CN9693
# OK: 881.png | RAW | PRJ140C2447 → RJ14QC2447
# OK: 882.png | RAW | RJ45CJ1568 → RJ45CJ1568
# OK: 883.png | RAW | FRJ45CU2324 → RJ45CU2324
# OK: 884.png | RAW | RJ20CD2031 → RJ20CD2031
# OK: 885.png | RAW | RJ14YC2665 → RJ14YC2665
# OK: 886.png | RAW | FRJ01CC1507 → RJ01CC1507
# OK: 887.png | RAW | RJ45CQ5065 → RJ45CQ5065
# OK: 888.png | RAW | FRJ14CW2950 → RJ14CW2950
# OK: 889.png | RAW | RJ45CP1665 → RJ45CP1665
# OK: 89.png | RAW | RJ14UG8714 → RJ14UG8714
# OK: 890.png | RAW | RJ14CV2530 → RJ14CV2530
# OK: 891.png | RAW | RJ45CL6572 → RJ45CL6572
# OK: 892.png | RAW | FRJ45CK7827 → RJ45CK7827
# OK: 893.png | RAW | RJ14CV6829 → RJ14CV6829
# OK: 894.png | RAW | -RJ45CJ1430 → RJ45CJ1430
# OK: 895.png | RAW | RJ45CN5222 → RJ45CN5222
# OK: 896.png | RAW | RJ14LC6851 → RJ14LC6851
# OK: 898.png | RAW | RJ 14 ZC 6586 → RJ14ZC6586
# OK: 899.png | RAW | FRJ45CK4536 → RJ45CK4536
# OK: 90.png | RAW | -RJ23CH0055 → RJ23CH0055
# OK: 900.png | RAW | RJ45CF6777 → RJ45CF6777
# OK: 901.png | RAW | FRJ45CK6065 → RJ45CK6065
# OK: 903.png | RAW | R J45CS7352 → RJ45CS7352
# OK: 904.png | RAW | -RJ18CE5772 → RJ18CE5772
# OK: 905.png | RAW | RJ14CN1514 → RJ14CN1514
# OK: 906.png | RAW | RJ25CA2829 → RJ25CA2829
# OK: 907.png | RAW | FRJ01CD3307 → RJ01CD3307
# OK: 908.png | RAW | RJ45CR8895 → RJ45CR8895
# OK: 909.png | RAW | RJ14UG5091 → RJ14UG5091
# OK: 91.png | RAW | RJ27CD0805 → RJ27CD0805
# OK: 910.png | RAW | RJ14CM5701 → RJ14CM5701
# OK: 911.png | RAW | RJ34CA6992 → RJ34CA6992
# OK: 912.png | RAW | RJ14CP3701 → RJ14CP3701
# OK: 913.png | RAW | FRJ14CT7895 → RJ14CT7895
# OK: 914.png | RAW | RJ45CN1428 → RJ45CN1428
# OK: 915.png | RAW | RJ01CC8226 → RJ01CC8226
# OK: 916.png | RAW | RJ14UH5605 → RJ14UH5605
# OK: 917.png | RAW | FRJ14CT7375 → RJ14CT7375
# OK: 918.png | RAW | RJ14CX2222 → RJ14CX2222
# OK: 919.png | RAW | RJ45 CE 5167 → RJ45CE5167
# OK: 920.png | RAW | RJ14WC7009 → RJ14WC7009
# OK: 921.png | RAW | RJ14CG7995 → RJ14CG7995
# OK: 922.png | RAW | RJ27CF8975 → RJ27CF8975
# OK: 923.png | RAW | RJ44CA5682 → RJ44CA5682
# OK: 925.png | RAW | RJ14CB0709 → RJ14CB0709
# OK: 926.png | RAW | RJ14WC2831 → RJ14WC2831
# OK: 927.png | RAW | RJ4CE 4878 → RJ4CE48780
# OK: 928.png | RAW | RJ14CH7630 → RJ14CH7630
# OK: 929.png | RAW | RJ14CT6066 → RJ14CT6066
# OK: 93.png | RAW | RJ45CJ0910 → RJ45CJ0910
# OK: 930.png | RAW | -RJ14YC1396 → RJ14YC1396
# OK: 932.png | RAW | RJ14CQ2418 → RJ14CQ2418
# OK: 933.png | RAW | RJ45CD0869 → RJ45CD0869
# OK: 934.png | RAW | RJ45CP9339 → RJ45CP9339
# OK: 935.png | RAW | RJ45CS5339 → RJ45CS5339
# OK: 936.png | RAW | RJ45CM8976 → RJ45CM8976
# OK: 937.png | RAW | -RJ14LC9273 → RJ14LC9273
# OK: 94.png | RAW | RJ14CW7295 → RJ14CW7295
# OK: 940.png | RAW | RJ14TE223 → RJ14TE2230
# OK: 941.png | RAW | RJ45CL7917 → RJ45CL7917
# OK: 943.png | RAW | RJ14UK3738 → RJ14UK3738
# OK: 990.png | RAW | RJ14CD7590 → RJ14CD7590
# OK: 992.png | RAW | RJ45CG0374 → RJ45CG0374
# OK: 993.png | RAW | RJ14CY3589 → RJ14CY3589
# OK: 994.png | RAW | RJ45CK5666 → RJ45CK5666
# OK: 995.png | RAW | RJ45CF2591 → RJ45CF2591
# OK: 996.png | RAW | RJ45CM6777 → RJ45CM6777
# OK: 997.png | RAW | -RJ07CD4085 → RJ07CD4085
# OK: 998.png | RAW | RJ36CA7025 → RJ36CA7025
# OK: 999.png | RAW | RJ140C5325 → RJ14QC5325
# DONE. Saved: hasil_adaptive_crop_QC_NO_PREPROC.csv

# %% [markdown]
# #EVALUATION RESULT (RAW CROPING YOLOv11)#

# %%
import csv, re

def clean_raw(text):
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def normalize_rj_fixedpos(raw_text):
    t = clean_raw(raw_text)
    if "RJ" in t:
        t = t[t.find("RJ"):]
    else:
        t = "RJ" + t
    t = (t + "0"*10)[:10]
    chars = list(t)
    chars[0], chars[1] = "R", "J"

    DIGIT_IDX = {2,3,6,7,8,9}
    ALPHA_IDX = {4,5}
    TO_DIGIT = {'O':'0','Q':'0','D':'0','I':'1','L':'1','Z':'2','S':'5','B':'8'}
    TO_ALPHA = {'0':'O','1':'I','2':'Z','5':'S','8':'B'}

    for i in range(10):
        if i in DIGIT_IDX and chars[i] in TO_DIGIT:
            chars[i] = TO_DIGIT[chars[i]]
        elif i in ALPHA_IDX and chars[i] in TO_ALPHA:
            chars[i] = TO_ALPHA[chars[i]]
    return "".join(chars)

def levenshtein(a, b):
    if a == b: return 0
    if not a: return len(b)
    if not b: return len(a)
    prev = list(range(len(b)+1))
    for i, ca in enumerate(a, 1):
        cur = [i]
        for j, cb in enumerate(b, 1):
            cur.append(min(cur[j-1]+1, prev[j]+1, prev[j-1]+(ca!=cb)))
        prev = cur
    return prev[-1]

# --- LOAD GT ---
GT_PATH = r"ground truth.txt"   # ganti jika perlu
gt = {}
with open(GT_PATH, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        if "\t" in line:
            img, plate = line.strip().split("\t")
            fname = img.split("/")[-1]
            gt[fname] = normalize_rj_fixedpos(plate)

# --- LOAD CSV ---
CSV_PATH = r"Result_Crop_Yolov11.csv"  # <-- CSV hasil pipeline
rows = []
with open(CSV_PATH, newline="", encoding="utf-8", errors="replace") as f:
    rows = list(csv.DictReader(f))

total = unreadable = readable = correct_e2e = 0
recog_total = recog_correct = 0
char_sum = 0.0

for r in rows:
    fname = r.get("File_Name","").strip()
    if fname not in gt: continue
    total += 1

    raw = r.get("Raw_OCR","").strip()
    conf_raw = r.get("Conf_0to1","").strip()
    try:
        conf = float(conf_raw)
    except:
        conf = 1.0 if raw != "" else 0.0

    if raw == "" or conf == 0.0:
        unreadable += 1
        continue

    readable += 1
    recog_total += 1

    pred = normalize_rj_fixedpos(r.get("Final_Plate",""))
    gt_plate = gt[fname]

    if pred == gt_plate:
        recog_correct += 1
        correct_e2e += 1

    dist = levenshtein(pred, gt_plate)
    char_sum += (1 - dist/10)

print("\n=== EVALUATION RESULT (RAW CROPING YOLOv11) ===")
print("Total samples       :", total)
print("Unreadable (OCR=∅)  :", unreadable)
print("Readable            :", readable)
print("----------------------------------")
print(f"Readability Rate          : {readable/total*100:.2f}%")
print(f"End-to-End Exact Accuracy : {correct_e2e/total*100:.2f}%")
if recog_total:
    print(f"Recognition Exact Acc     : {recog_correct/recog_total*100:.2f}%")
    print(f"Average Character Acc     : {char_sum/recog_total*100:.2f}%")
# Out:
# === EVALUATION RESULT (RAW CROPING YOLOv11) ===
# Total samples       : 750
# Unreadable (OCR=∅)  : 8
# Readable            : 742
# ----------------------------------
# Readability Rate          : 98.93%
# End-to-End Exact Accuracy : 89.33%
# Recognition Exact Acc     : 90.30%
# Average Character Acc     : 97.41%

# %% [markdown]
# #PaddeOCR Real-ESRGAN #

# %%
import os
import csv
import re
import cv2
from paddleocr import PaddleOCR

# ============================================================
# 0) CONFIG
# ============================================================
INPUT_FOLDER = r"D:\Uniska\~Disertasi\~Projek Jurnal\sr_crops-SR"  
OUT_CSV      = r"Result_crop_REAL-ESRGAN.csv"          

# ============================================================
# 1) OCR INIT
# ============================================================
ocr = PaddleOCR(
    use_angle_cls=True,
    lang='en',
    show_log=False,
    det_db_thresh=0.3
)

# ============================================================
# 2) BASIC HELPERS
# ============================================================
def clean_raw(text: str) -> str:
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def pick_best_line(result):
    
    if result is None:
        return "", 0.0
    if not isinstance(result, list) or len(result) == 0:
        return "", 0.0

    # kasus umum: result = [ [line1, line2, ...] ]
    lines = result[0] if (len(result) == 1 and isinstance(result[0], list)) else result
    if lines is None:
        return "", 0.0

    best_text, best_conf = "", 0.0
    for line in lines:
        try:
            txt = line[1][0]
            conf = float(line[1][1])
        except Exception:
            continue
        if conf > best_conf and txt:
            best_text, best_conf = str(txt), conf
    return best_text, best_conf

# ============================================================
# 3) VARIANTS (TANPA CLAHE & TANPA SR2x)
# ============================================================
def make_variants(img):
    # Hanya RAW (no preprocessing)
    return [("RAW", img)]
    # Jika mau pembanding ringan tapi tetap tanpa CLAHE/SR:
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # return [("RAW", img), ("GRAY", gray)]

# ============================================================
# 4) NORMALIZATION (RJ fixed position)
# ============================================================
def normalize_rj_fixedpos_with_meta(raw_text: str):
    """
    Normalisasi plat format fixed-length=10:
      [0]=R, [1]=J, [2-3]=digit, [4-5]=alpha, [6-9]=digit
    Return: final_plate (str), casts (int), anchor_bonus (float)
    """
    t0 = clean_raw(raw_text)

    # 1) Anchor RJ
    anchor_bonus = 0.0
    if "RJ" in t0:
        anchor_bonus = 0.15
        t = t0[t0.find("RJ"):]
    else:
        t = "RJ" + t0

    # 2) Enforce length 10
    if len(t) < 10:
        t = t.ljust(10, "0")
    else:
        t = t[:10]

    chars = list(t)

    # Hard prefix
    chars[0], chars[1] = "R", "J"

    # 3) Casting berbasis posisi
    digit_idx = {2, 3, 6, 7, 8, 9}
    alpha_idx = {4, 5}

    to_digit = {
        "O": "0", "Q": "0", "D": "0",
        "I": "1", "L": "1",
        "Z": "2",
        "S": "5",
        "B": "8",
    }
    to_alpha = {"0": "O", "1": "I", "2": "Z", "5": "S", "8": "B"}

    casts = 0

    for i in range(10):
        c = chars[i]

        if i in digit_idx and c in to_digit:
            newc = to_digit[c]
            if newc != c:
                chars[i] = newc
                casts += 1

        elif i in alpha_idx and c in to_alpha:
            newc = to_alpha[c]
            if newc != c:
                chars[i] = newc
                casts += 1

    # 4) Rule khusus pasangan ambiguitas pada posisi [4-5]
    #    Mendukung: OC, CO, 0C, C0  -> Target QC / CQ
    pair = chars[4] + chars[5]
    pair_map = {
        "OC": ("Q", "C"),
        "CO": ("C", "Q"),
        "0C": ("Q", "C"),
        "C0": ("C", "Q"),
    }
    if pair in pair_map:
        new4, new5 = pair_map[pair]
        if (chars[4], chars[5]) != (new4, new5):
            chars[4], chars[5] = new4, new5
            casts += 1

    final_plate = "".join(chars)
    return final_plate, casts, anchor_bonus

def struct_score_rj(plate10: str) -> float:
    if not plate10 or len(plate10) != 10:
        return 0.0
    c = list(plate10)
    ok = 0
    ok += 1 if c[0] == "R" else 0
    ok += 1 if c[1] == "J" else 0
    for i in [2, 3, 6, 7, 8, 9]:
        ok += 1 if c[i].isdigit() else 0
    for i in [4, 5]:
        ok += 1 if c[i].isalpha() else 0
    return ok / 10.0

# ============================================================
# 5) QC/CQ AMBIGUITY FIX WITH GATE (FIXED INDENTATION)
# ============================================================
def apply_qc_gate(plate10: str, raw_text: str, other_candidates_have_qpair: bool):
    """
    Fix:
      OC -> QC
      CO -> CQ
      0C -> QC
      C0 -> CQ
    ONLY if evidence (gate):
      - raw OCR text contains 'Q' anywhere, OR
      - another variant produced QC/CQ explicitly
    Return: (new_plate, add_cast)
    """
    if not plate10 or len(plate10) != 10:
        return plate10, 0

    chars = list(plate10)
    pair = chars[4] + chars[5]
    if pair not in ("OC", "CO", "0C", "C0"):
        return plate10, 0

    t = clean_raw(raw_text)
    gate_raw_has_q = ("Q" in t)
    gate_other = bool(other_candidates_have_qpair)

    if not (gate_raw_has_q or gate_other):
        return plate10, 0

    if pair == "OC":
        chars[4], chars[5] = "Q", "C"
        return "".join(chars), 1
    if pair == "CO":
        chars[4], chars[5] = "C", "Q"
        return "".join(chars), 1
    if pair == "0C":
        chars[4], chars[5] = "Q", "C"
        return "".join(chars), 1
    if pair == "C0":
        chars[4], chars[5] = "C", "Q"
        return "".join(chars), 1

    return plate10, 0

# ============================================================
# 6) PLATE-AWARE SCORING
# ============================================================
def score_candidate(conf, struct_score, casts, anchor_bonus):
    w_conf = 0.55
    w_struct = 0.45
    cast_penalty = min(casts, 6) * 0.02  # max 0.12
    return (w_conf * float(conf)) + (w_struct * float(struct_score)) + float(anchor_bonus) - cast_penalty

def select_best_across_variants(variant_results):
    """
    variant_results: list of (variant_name, paddle_result)
    Return dict best or None
    """
    # gate evidence: apakah ada kandidat yang eksplisit menghasilkan QC/CQ di raw OCR?
    other_has_qpair = False
    for vname, pres in variant_results:
        raw_text, conf = pick_best_line(pres)
        if not raw_text:
            continue
        t = clean_raw(raw_text)
        if ("QC" in t) or ("CQ" in t):
            other_has_qpair = True
            break

    best = None
    for vname, pres in variant_results:
        raw_text, conf = pick_best_line(pres)
        if not raw_text:
            continue

        final_plate, casts, anchor_bonus = normalize_rj_fixedpos_with_meta(raw_text)

        # apply gated ambiguity fix
        final_plate2, add_cast = apply_qc_gate(final_plate, raw_text, other_has_qpair)
        casts += add_cast
        final_plate = final_plate2

        s_struct = struct_score_rj(final_plate)
        s_total = score_candidate(conf, s_struct, casts, anchor_bonus)

        cand = {
            "variant": vname,
            "raw_text": raw_text,
            "final_plate": final_plate,
            "conf": float(conf),
            "score_total": float(s_total),
            "casts": int(casts),
            "struct_score": float(s_struct),
            "anchor_bonus": float(anchor_bonus),
        }

        if (best is None) or (cand["score_total"] > best["score_total"]):
            best = cand

    return best

# ============================================================
# 7) MAIN LOOP -> CSV
# ============================================================
image_files = sorted([
    f for f in os.listdir(INPUT_FOLDER)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
])

with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow([
        "File_Name","Variant","Raw_OCR","Final_Plate",
        "Conf_0to1","Score","Casts","StructScore","AnchorBonus"
    ])

    for fn in image_files:
        img_path = os.path.join(INPUT_FOLDER, fn)
        img = cv2.imread(img_path)

        if img is None:
            w.writerow([fn,"","","",0,0,0,0,0])
            print("BAD IMAGE:", fn)
            continue

        variant_results = []
        for vname, vimg in make_variants(img):
            try:
                pres = ocr.ocr(vimg, cls=True)
            except Exception:
                pres = None
            variant_results.append((vname, pres))

        best = select_best_across_variants(variant_results)

        if best is None:
            w.writerow([fn,"","","",0,0,0,0,0])
            print("NO TEXT:", fn)
        else:
            w.writerow([
                fn,
                best["variant"],
                best["raw_text"],
                best["final_plate"],
                round(best["conf"], 6),
                round(best["score_total"], 6),
                best["casts"],
                round(best["struct_score"], 6),
                round(best["anchor_bonus"], 6)
            ])
            print(f"OK: {fn} | {best['variant']} | {best['raw_text']} → {best['final_plate']}")

print("DONE. Saved:", OUT_CSV)
# Out:
# OK: 100.png | RAW | RJ45 CK4748 → RJ45CK4748
# OK: 1000.png | RAW | RJ14CG6581 → RJ14CG6581
# OK: 1001.png | RAW | RJ14CK0305 → RJ14CK0305
# OK: 101.png | RAW | "RJ14CZ0391 → RJ14CZ0391
# OK: 102.png | RAW | RJ45CH4583 → RJ45CH4583
# OK: 103.png | RAW | RJ45CJ9969 → RJ45CJ9969
# OK: 104.png | RAW | RJ14LC6763 → RJ14LC6763
# OK: 105.png | RAW | FRJ31CF7171 → RJ31CF7171
# OK: 106.png | RAW | RJ08CA6767 → RJ08CA6767
# OK: 107.png | RAW | -RJ45CN9693 → RJ45CN9693
# OK: 108.png | RAW | RJ45CK7827 → RJ45CK7827
# OK: 109.png | RAW | FRJ45CQ1702 → RJ45CQ1702
# OK: 111.png | RAW | RJ14 CF 9928 → RJ14CF9928
# OK: 112.png | RAW | RJ45C09137 → RJ45CQ9137
# OK: 113.png | RAW | RJ14CY6039 → RJ14CY6039
# OK: 114.png | RAW | 9094 → RJ90940000
# OK: 115.png | RAW | RJ14VC0628 → RJ14VC0628
# OK: 217.png | RAW | ERJ14TF0294 → RJ14TF0294
# OK: 218.png | RAW | RJ45CL7067 → RJ45CL7067
# OK: 219.png | RAW | RJ45CR6853 → RJ45CR6853
# OK: 220.png | RAW | RJ14CQ3553 → RJ14CQ3553
# OK: 221.png | RAW | RJ14CB0709 → RJ14CB0709
# OK: 222.png | RAW | RJ14C00560 → RJ14CQ0560
# OK: 223.png | RAW | RJ14ZC4023 → RJ14ZC4023
# OK: 224.png | RAW | RJ14VC4981 → RJ14VC4981
# OK: 225.png | RAW | RJ45C02581 → RJ45CQ2581
# OK: 226.png | RAW | RJ14 → RJ14OO0000
# OK: 227.png | RAW | RJ14 CL 4477 → RJ14CL4477
# OK: 228.png | RAW | RJ01CB9294 → RJ01CB9294
# OK: 229.png | RAW | RJ14CV1286 → RJ14CV1286
# OK: 230.png | RAW | "RJ45CT4349 → RJ45CT4349
# OK: 231.png | RAW | RJ14CX9236 → RJ14CX9236
# OK: 232.png | RAW | RJ14VC6735 → RJ14VC6735
# OK: 233.png | RAW | RJ01CE3953 → RJ01CE3953
# OK: 234.png | RAW | RJ14 YC 3009 → RJ14YC3009
# OK: 235.png | RAW | RJ14 CN 6419 → RJ14CN6419
# OK: 236.png | RAW | RJ14CZ5492 → RJ14CZ5492
# OK: 237.png | RAW | RJ148C 5315 → RJ14BC5315
# OK: 238.png | RAW | RJ14CY9553 → RJ14CY9553
# OK: 239.png | RAW | RJ14C03981 → RJ14CQ3981
# OK: 240.png | RAW | RJ140C9673 → RJ14QC9673
# OK: 241.png | RAW | RJ14U02000 → RJ14UO2000
# OK: 242.png | RAW | RJ45CK1303 → RJ45CK1303
# OK: 243.png | RAW | -RJ45CL6966 → RJ45CL6966
# OK: 244.png | RAW | RJ14VC3804 → RJ14VC3804
# OK: 245.png | RAW | RJ45CT4296 → RJ45CT4296
# OK: 246.png | RAW | RJ14UH7714 → RJ14UH7714
# OK: 247.png | RAW | IND → RJ1NDO0000
# OK: 248.png | RAW | RJ45CJ3253 → RJ45CJ3253
# OK: 249.png | RAW | RJ14CP6854 → RJ14CP6854
# OK: 250.png | RAW | RJ45CL3942 → RJ45CL3942
# OK: 251.png | RAW | ~RJ45CH2013 → RJ45CH2013
# OK: 252.png | RAW | RJ45CN0760 → RJ45CN0760
# OK: 253.png | RAW | RJ14CF9305 → RJ14CF9305
# OK: 254.png | RAW | RJ14TE0155 → RJ14TE0155
# OK: 255.png | RAW | RJ14 CC 6396 → RJ14CC6396
# OK: 256.png | RAW | RJ45CH4653 → RJ45CH4653
# OK: 257.png | RAW | RJ45CJ5975 → RJ45CJ5975
# OK: 258.png | RAW | RJ14 CJ 3755 → RJ14CJ3755
# OK: 259.png | RAW | PRJ14UJ7600 → RJ14UJ7600
# OK: 260.png | RAW | RJ45CL7457 → RJ45CL7457
# OK: 261.png | RAW | RJ45 CD 00I9 → RJ45CD0019
# OK: 262.png | RAW | RJ14CE1623 → RJ14CE1623
# OK: 263.png | RAW | RJ45CM1052 → RJ45CM1052
# OK: 265.png | RAW | RJOP6207 → RJ0P6Z0700
# OK: 375.png | RAW | RJ19TA.0994 → RJ19TA0994
# OK: 377.png | RAW | RJ14CY7851 → RJ14CY7851
# OK: 379.png | RAW | RJ45CQ4036 → RJ45CQ4036
# OK: 380.png | RAW | RJ14CK0008 → RJ14CK0008
# OK: 381.png | RAW | D → RJ00OO0000
# OK: 382.png | RAW | "RJ14UD5383 → RJ14UD5383
# OK: 383.png | RAW | RJ40CA1097 → RJ40CA1097
# OK: 386.png | RAW | RJ45 CE 4246 → RJ45CE4246
# OK: 387.png | RAW | RJ45CT1012 → RJ45CT1012
# OK: 388.png | RAW | RJ14CR5019 → RJ14CR5019
# OK: 389.png | RAW | RJ 23UB6081 → RJ23UB6081
# OK: 390.png | RAW | RJ02CC6621 → RJ02CC6621
# OK: 391.png | RAW | RJ21UG0044 → RJ21UG0044
# OK: 392.png | RAW | RJ14UF1632 → RJ14UF1632
# OK: 393.png | RAW | RJ45CT9496 → RJ45CT9496
# OK: 394.png | RAW | RJ18 CD 2193 → RJ18CD2193
# OK: 395.png | RAW | RJ'02 CC 4642 → RJ02CC4642
# OK: 396.png | RAW | RJ14UG8209 → RJ14UG8209
# OK: 397.png | RAW | RJ45CP5704 → RJ45CP5704
# OK: 398.png | RAW | RJ45CA2953 → RJ45CA2953
# OK: 399.png | RAW | RJ45CR2576 → RJ45CR2576
# OK: 400.png | RAW | RJ13CB6214 → RJ13CB6214
# OK: 401.png | RAW | RJ4CL1162 → RJ4CLI1620
# OK: 402.png | RAW | RJ14 ZC 2864 → RJ14ZC2864
# OK: 403.png | RAW | RJ14CU5325 → RJ14CU5325
# OK: 404.png | RAW | RJ140H7046 → RJ14OH7046
# OK: 405.png | RAW | RJ14TD0733 → RJ14TD0733
# OK: 406.png | RAW | RJ45CS0617 → RJ45CS0617
# OK: 407.png | RAW | RJ14TB4095 → RJ14TB4095
# OK: 408.png | RAW | RJ45CT6689 → RJ45CT6689
# OK: 409.png | RAW | RJ14TB1265 → RJ14TB1265
# OK: 410.png | RAW | RJ14T87738 → RJ14TB7738
# OK: 411.png | RAW | RJ14TD0908 → RJ14TD0908
# OK: 412.png | RAW | RJ14TD4148 → RJ14TD4148
# OK: 413.png | RAW | RJ14UD8337 → RJ14UD8337
# OK: 414.png | RAW | RJ06UA9743 → RJ06UA9743
# OK: 415.png | RAW | RJ14T07268 → RJ14TO7268
# OK: 416.png | RAW | RJ47TA0568 → RJ47TA0568
# OK: 417.png | RAW | RJ14TB7210 → RJ14TB7210
# OK: 418.png | RAW | RJ18CD3382 → RJ18CD3382
# OK: 419.png | RAW | RJ23UA4493 → RJ23UA4493
# OK: 420.png | RAW | 6RJ14UH4591 → RJ14UH4591
# OK: 421.png | RAW | RJ14T89315 → RJ14TB9315
# OK: 423.png | RAW | RJ22UB1551 → RJ22UB1551
# OK: 425.png | RAW | "RJ45CT3790 → RJ45CT3790
# OK: 426.png | RAW | "RJ45CT1885 → RJ45CT1885
# OK: 427.png | RAW | "RJ45CT3790 → RJ45CT3790
# OK: 428.png | RAW | "RJ07CD5141 → RJ07CD5141
# OK: 554.png | RAW | RJ45CF9239 → RJ45CF9239
# OK: 555.png | RAW | RJ14XC1470 → RJ14XC1470
# OK: 556.png | RAW | RJ19CE1032 → RJ19CE1032
# OK: 557.png | RAW | "RJ14WC2203 → RJ14WC2203
# OK: 558.png | RAW | "RJ45CS5230 → RJ45CS5230
# OK: 559.png | RAW | PRJ45CK0487 → RJ45CK0487
# OK: 560.png | RAW | RJ14 CL 7291 → RJ14CL7291
# OK: 561.png | RAW | RJ14CU8301 → RJ14CU8301
# OK: 563.png | RAW | RJ40UA1802 → RJ40UA1802
# OK: 564.png | RAW | RJ14HC9272 → RJ14HC9272
# OK: 566.png | RAW | RJ45CS0638 → RJ45CS0638
# OK: 568.png | RAW | RJ14CL8997 → RJ14CL8997
# OK: 569.png | RAW | RJ14UG9738 → RJ14UG9738
# OK: 570.png | RAW | RJ04CA7197 → RJ04CA7197
# OK: 571.png | RAW | cRJ14ZC8007 → RJ14ZC8007
# OK: 573.png | RAW | RJ14UH0436 → RJ14UH0436
# OK: 574.png | RAW | "RJ14LC4620 → RJ14LC4620
# OK: 576.png | RAW | RJ14CU5539 → RJ14CU5539
# OK: 577.png | RAW | RJ14CL4005 → RJ14CL4005
# OK: 578.png | RAW | RJ45CM4942 → RJ45CM4942
# OK: 579.png | RAW | RJ14CM6318 → RJ14CM6318
# OK: 580.png | RAW | RJ45 CA 2095 → RJ45CA2095
# OK: 581.png | RAW | RJ14XC6684 → RJ14XC6684
# OK: 582.png | RAW | "RJ14AC7435 → RJ14AC7435
# OK: 583.png | RAW | RJ14C04852 → RJ14CQ4852
# OK: 584.png | RAW | 5905 → RJ59OS0000
# OK: 585.png | RAW | RJ14 CM 1812 → RJ14CM1812
# OK: 586.png | RAW | "RJ14UG4439 → RJ14UG4439
# OK: 587.png | RAW | "RJ21CA5505 → RJ21CA5505
# OK: 588.png | RAW | "RJ14YC4911 → RJ14YC4911
# OK: 591.png | RAW | RJ18UC0731 → RJ18UC0731
# OK: 593.png | RAW | RJ14XC5483 → RJ14XC5483
# OK: 594.png | RAW | RJ19-CC-8131 → RJ19CC8131
# OK: 595.png | RAW | RJ45CL7121 → RJ45CL7121
# OK: 597.png | RAW | "RJ14CT6932 → RJ14CT6932
# OK: 598.png | RAW | RJ14CJ2806 → RJ14CJ2806
# OK: 60.png | RAW | RJ45CG8893 → RJ45CG8893
# OK: 600.png | RAW | RJ45 CF 8413 → RJ45CF8413
# OK: 601.png | RAW | "RJ45CE6832 → RJ45CE6832
# OK: 602.png | RAW | RJ45CP5873 → RJ45CP5873
# OK: 604.png | RAW | RJ14CV6896 → RJ14CV6896
# OK: 605.png | RAW | "RJ14XC9225 → RJ14XC9225
# OK: 607.png | RAW | "RJ45CH3180 → RJ45CH3180
# OK: 609.png | RAW | RJ20CH0018 → RJ20CH0018
# OK: 61.png | RAW | "RJ44CA5682 → RJ44CA5682
# OK: 610.png | RAW | "RJ45CJ0248 → RJ45CJ0248
# OK: 613.png | RAW | RJ45CH4066 → RJ45CH4066
# OK: 710.png | RAW | PRJ45CP6844 → RJ45CP6844
# OK: 711.png | RAW | RJ45CD5708 → RJ45CD5708
# OK: 712.png | RAW | RJ45CH2533 → RJ45CH2533
# OK: 714.png | RAW | "oRJ14YC7682 → RJ14YC7682
# OK: 72.png | RAW | RJ45CN2934 → RJ45CN2934
# OK: 74.png | RAW | RJ45C00611 → RJ45CQ0611
# OK: 75.png | RAW | FRJ14C79166 → RJ14C79166
# OK: 76.png | RAW | RJ45CJ5099 → RJ45CJ5099
# OK: 77.png | RAW | -RJ45CU5747 → RJ45CU5747
# OK: 78.png | RAW | BJ144L4748 → RJ8JI44147
# OK: 80.png | RAW | FRJ18CE4818 → RJ18CE4818
# OK: 803.png | RAW | RJ14CK1537 → RJ14CK1537
# OK: 804.png | RAW | ~RJ45CP1891 → RJ45CP1891
# OK: 805.png | RAW | -RJ45CS9822 → RJ45CS9822
# OK: 807.png | RAW | FRJ47CA3067 → RJ47CA3067
# OK: 808.png | RAW | RJ14CY0301 → RJ14CY0301
# OK: 809.png | RAW | RJ14 CK 5851 → RJ14CK5851
# OK: 81.png | RAW | *RJ27CD0805 → RJ27CD0805
# OK: 810.png | RAW | RJ-Q1-VA1712 → RJ01VA1712
# OK: 811.png | RAW | RJ14UD9814 → RJ14UD9814
# OK: 812.png | RAW | RJ45CN3445 → RJ45CN3445
# OK: 813.png | RAW | RJ14CT2837 → RJ14CT2837
# OK: 814.png | RAW | *RJ45CH0091 → RJ45CH0091
# OK: 815.png | RAW | RJ O2 CF l365 → RJ02CF1365
# OK: 816.png | RAW | RJ14CE1733 → RJ14CE1733
# OK: 817.png | RAW | RJ45C09259 → RJ45CQ9259
# OK: 818.png | RAW | RJ45CK8330 → RJ45CK8330
# OK: 82.png | RAW | RJ29CA5938 → RJ29CA5938
# OK: 820.png | RAW | FRJ45CJ6486 → RJ45CJ6486
# OK: 821.png | RAW | PRJ14CZ3108 → RJ14CZ3108
# OK: 822.png | RAW | PRJ14HC9541 → RJ14HC9541
# OK: 823.png | RAW | RJ14CV4657 → RJ14CV4657
# OK: 824.png | RAW | RJ14 UF8669 → RJ14UF8669
# OK: 825.png | RAW | PRJ15UA1109 → RJ15UA1109
# OK: 826.png | RAW | RJ140H1563 → RJ14OH1563
# OK: 827.png | RAW | -RJ14CV1914 → RJ14CV1914
# OK: 828.png | RAW | RJ07CA5369 → RJ07CA5369
# OK: 829.png | RAW | RJ14 ZC9897 → RJ14ZC9897
# OK: 83.png | RAW | RJ10CA5546 → RJ10CA5546
# OK: 830.png | RAW | -RJ45CU7408 → RJ45CU7408
# OK: 831.png | RAW | RJ14UG8787 → RJ14UG8787
# OK: 832.png | RAW | PRJ40CA7299 → RJ40CA7299
# OK: 833.png | RAW | RJ14CZ8986 → RJ14CZ8986
# OK: 834.png | RAW | RJ14CZ5755 → RJ14CZ5755
# OK: 835.png | RAW | ~RJ14CA9687 → RJ14CA9687
# OK: 836.png | RAW | RJ45CF1633 → RJ45CF1633
# OK: 837.png | RAW | RJ45CV6466 → RJ45CV6466
# OK: 838.png | RAW | "RJ45CV6605 → RJ45CV6605
# OK: 839.png | RAW | RJ45CN0022 → RJ45CN0022
# OK: 84.png | RAW | RJ44CA2231 → RJ44CA2231
# OK: 840.png | RAW | RJ05CC0003 → RJ05CC0003
# OK: 841.png | RAW | PRJ14CW9269 → RJ14CW9269
# OK: 842.png | RAW | RJ14C05690 → RJ14CQ5690
# OK: 843.png | RAW | RJ45CG7702 → RJ45CG7702
# OK: 844.png | RAW | RJ14ZC7793 → RJ14ZC7793
# OK: 845.png | RAW | 'RJ14UE5553 → RJ14UE5553
# OK: 846.png | RAW | -RJ45CL2546 → RJ45CL2546
# OK: 847.png | RAW | RJ14 CL 0535 → RJ14CL0535
# OK: 848.png | RAW | RJ45C07703 → RJ45CQ7703
# OK: 849.png | RAW | RJ45CS4737 → RJ45CS4737
# OK: 85.png | RAW | -RJ45CL4740 → RJ45CL4740
# OK: 850.png | RAW | -RJ45CV1494 → RJ45CV1494
# OK: 851.png | RAW | PRJ14CX3108 → RJ14CX3108
# OK: 852.png | RAW | RJ14CC0979 → RJ14CC0979
# OK: 853.png | RAW | RJ45CP6364 → RJ45CP6364
# OK: 854.png | RAW | PRJ14WC1303 → RJ14WC1303
# OK: 856.png | RAW | RJ45CP8366 → RJ45CP8366
# OK: 857.png | RAW | RJ14C03372 → RJ14CQ3372
# OK: 858.png | RAW | RJ147C0010 → RJ147C0010
# OK: 859.png | RAW | PRJ14CT7262 → RJ14CT7262
# OK: 86.png | RAW | RJ45CM6898 → RJ45CM6898
# OK: 861.png | RAW | PRJ14TE0516 → RJ14TE0516
# OK: 862.png | RAW | PRJ45CU1237 → RJ45CU1237
# OK: 863.png | RAW | RJ29CA5938 → RJ29CA5938
# OK: 864.png | RAW | RJ14_CE 3763 → RJ14CE3763
# OK: 865.png | RAW | RJ14CZ6795 → RJ14CZ6795
# OK: 866.png | RAW | RJ14UH0270 → RJ14UH0270
# OK: 867.png | RAW | RJ45CH1213 → RJ45CH1213
# OK: 868.png | RAW | RJ45CU1897 → RJ45CU1897
# OK: 869.png | RAW | RJ29CA7848 → RJ29CA7848
# OK: 87.png | RAW | -RJ45CU3690 → RJ45CU3690
# OK: 870.png | RAW | ERJ45CV0109 → RJ45CV0109
# OK: 871.png | RAW | -RJ14CC8393 → RJ14CC8393
# OK: 872.png | RAW | 313418 → RJ31341800
# OK: 873.png | RAW | RJ14TD0741 → RJ14TD0741
# OK: 874.png | RAW | RJ14CY5022 → RJ14CY5022
# OK: 875.png | RAW | RJ14C86100 → RJ14CB6100
# OK: 876.png | RAW | RJ21CB 3598 → RJ21CB3598
# OK: 877.png | RAW | RJ45CE3482 → RJ45CE3482
# OK: 878.png | RAW | PRJ14UJ0992 → RJ14UJ0992
# OK: 879.png | RAW | PRJO8CA6767 → RJ08CA6767
# OK: 88.png | RAW | -RJ45CL4097 → RJ45CL4097
# OK: 880.png | RAW | RJ45CN9693 → RJ45CN9693
# OK: 881.png | RAW | PRJ140C2447 → RJ14QC2447
# OK: 882.png | RAW | "RJ45CJ1568 → RJ45CJ1568
# OK: 883.png | RAW | RJ45CU2324 → RJ45CU2324
# OK: 884.png | RAW | RJ20CD2031 → RJ20CD2031
# OK: 885.png | RAW | RJ14YC2665 → RJ14YC2665
# OK: 886.png | RAW | RJ01CC1507 → RJ01CC1507
# OK: 887.png | RAW | RJ45C05065 → RJ45CQ5065
# OK: 888.png | RAW | RJ14CW2950 → RJ14CW2950
# OK: 889.png | RAW | RJ45CP1665 → RJ45CP1665
# OK: 89.png | RAW | "RJ14UG8714 → RJ14UG8714
# OK: 890.png | RAW | RJ14CV2530 → RJ14CV2530
# OK: 891.png | RAW | RJ45CL6572 → RJ45CL6572
# OK: 892.png | RAW | RJ45CK7827 → RJ45CK7827
# OK: 893.png | RAW | -RJ14CV6829 → RJ14CV6829
# OK: 894.png | RAW | -RJ45CJ1430 → RJ45CJ1430
# OK: 895.png | RAW | RJ45CN5222 → RJ45CN5222
# OK: 896.png | RAW | RJ14LC6851 → RJ14LC6851
# OK: 898.png | RAW | RJ 14 ZC 6586 → RJ14ZC6586
# OK: 899.png | RAW | FRJ45CK4536 → RJ45CK4536
# OK: 90.png | RAW | ~RJ23CH0055 → RJ23CH0055
# OK: 900.png | RAW | <RJ45CF6777 → RJ45CF6777
# OK: 901.png | RAW | RJ45CK6065 → RJ45CK6065
# OK: 903.png | RAW | RJ45CS7352 → RJ45CS7352
# OK: 904.png | RAW | RJ18CE5772 → RJ18CE5772
# OK: 905.png | RAW | RJ14CN1514 → RJ14CN1514
# OK: 906.png | RAW | J25CA2829 → RJJ2SCA282
# OK: 907.png | RAW | RJ01CD3307 → RJ01CD3307
# OK: 908.png | RAW | RJ45CR8895 → RJ45CR8895
# OK: 909.png | RAW | "RJ14UG5091 → RJ14UG5091
# OK: 91.png | RAW | *RJ27CD0805 → RJ27CD0805
# OK: 910.png | RAW | RJ14 CM 5701 → RJ14CM5701
# OK: 911.png | RAW | RJ34CA6992 → RJ34CA6992
# OK: 912.png | RAW | sRJ14CP3701 → RJ14CP3701
# OK: 913.png | RAW | RJ14CT7895 → RJ14CT7895
# OK: 914.png | RAW | RJ45CN1428 → RJ45CN1428
# OK: 915.png | RAW | RJ01CC8226 → RJ01CC8226
# OK: 916.png | RAW | RJ14UH5605 → RJ14UH5605
# OK: 917.png | RAW | -RJ14CT7375 → RJ14CT7375
# OK: 918.png | RAW | RJ14CX2222 → RJ14CX2222
# OK: 919.png | RAW | RJ45 CE 5167 → RJ45CE5167
# OK: 920.png | RAW | RJ14WC7009 → RJ14WC7009
# OK: 921.png | RAW | RJ14CG7995 → RJ14CG7995
# OK: 922.png | RAW | -RJ27CF8975 → RJ27CF8975
# OK: 923.png | RAW | "RJ44CA5682 → RJ44CA5682
# OK: 925.png | RAW | RJ14C80709 → RJ14CB0709
# OK: 926.png | RAW | PRJ14WC2831 → RJ14WC2831
# OK: 927.png | RAW | RJ14 CE 4878 → RJ14CE4878
# OK: 928.png | RAW | RJ14CH7630 → RJ14CH7630
# OK: 929.png | RAW | RJ14CT6066 → RJ14CT6066
# OK: 93.png | RAW | RJ45CJ0910 → RJ45CJ0910
# OK: 930.png | RAW | -RJ14YC1396 → RJ14YC1396
# OK: 932.png | RAW | RJ14CQ2418 → RJ14CQ2418
# OK: 933.png | RAW | RJ45CD0869 → RJ45CD0869
# OK: 934.png | RAW | RJ45CP9339 → RJ45CP9339
# OK: 935.png | RAW | RJ45CS5339 → RJ45CS5339
# OK: 936.png | RAW | *RJ45CH8976 → RJ45CH8976
# OK: 937.png | RAW | RJ14LC9273 → RJ14LC9273
# OK: 94.png | RAW | SRJ14CH7295 → RJ14CH7295
# OK: 940.png | RAW | RJ14TE223 → RJ14TE2230
# OK: 941.png | RAW | RJ45CL7917 → RJ45CL7917
# OK: 943.png | RAW | "RJ14UK3738 → RJ14UK3738
# OK: 944.png | RAW | RJ14 CK 7225 → RJ14CK7225
# OK: 945.png | RAW | RJ14LC9745 → RJ14LC9745
# OK: 946.png | RAW | RJ20CF3549 → RJ20CF3549
# OK: 947.png | RAW | PRJ45CS2356 → RJ45CS2356
# OK: 948.png | RAW | FRJ140C0039 → RJ14QC0039
# OK: 949.png | RAW | =RJ45C66212 → RJ45C66212
# OK: 95.png | RAW | IND → RJ1NDO0000
# OK: 950.png | RAW | RJ03CA0112 → RJ03CA0112
# OK: 951.png | RAW | RJ07C86719 → RJ07CB6719
# OK: 952.png | RAW | PRJ14UG5129 → RJ14UG5129
# OK: 953.png | RAW | -RJ14CP6305 → RJ14CP6305
# OK: 954.png | RAW | RJ14XC3991 → RJ14XC3991
# OK: 955.png | RAW | RJ45CT7757 → RJ45CT7757
# OK: 956.png | RAW | PRJIOCA7007 → RJ10CA7007
# OK: 957.png | RAW | RJ14CT4486 → RJ14CT4486
# OK: 958.png | RAW | RJ02CC3703 → RJ02CC3703
# OK: 959.png | RAW | ERJ14VC7282 → RJ14VC7282
# OK: 96.png | RAW | RJ14VC4705 → RJ14VC4705
# OK: 960.png | RAW | -RJ14NC3463 → RJ14NC3463
# OK: 961.png | RAW | RJ45CG7977 → RJ45CG7977
# OK: 962.png | RAW | RJ45CE6848 → RJ45CE6848
# OK: 963.png | RAW | RJ14C19747 → RJ14CI9747
# OK: 964.png | RAW | RJ45CJ8172 → RJ45CJ8172
# OK: 965.png | RAW | RJ45CE 9904 → RJ45CE9904
# OK: 966.png | RAW | -RJ14VC9553 → RJ14VC9553
# OK: 968.png | RAW | RJ20CB5507 → RJ20CB5507
# OK: 969.png | RAW | RJ14CL4698 → RJ14CL4698
# OK: 97.png | RAW | RJ14CY5251 → RJ14CY5251
# OK: 970.png | RAW | AJi4CT o51 → RJAJI4CT05
# OK: 972.png | RAW | RJ14UF0093 → RJ14UF0093
# OK: 973.png | RAW | RJ14Ch 8599 → RJ14CH8599
# OK: 974.png | RAW | RJ45C00229 → RJ45CQ0229
# OK: 975.png | RAW | RJ140C1197 → RJ14QC1197
# OK: 977.png | RAW | RJ140X7010 → RJ14OX7010
# OK: 979.png | RAW | RJ14CK0216 → RJ14CK0216
# OK: 98.png | RAW | FRJ14UH9149 → RJ14UH9149
# OK: 980.png | RAW | RJ14CV8966 → RJ14CV8966
# OK: 981.png | RAW | PRJ45CP0711 → RJ45CP0711
# OK: 982.png | RAW | -RJ14CJ5999 → RJ14CJ5999
# OK: 983.png | RAW | FAJOOCA9288 → RJFAJO0CA9
# OK: 984.png | RAW | RJ14TE2451 → RJ14TE2451
# OK: 985.png | RAW | RI4 cza493 → RJR14C2A49
# OK: 986.png | RAW | PRJ14WC1332 → RJ14WC1332
# OK: 987.png | RAW | PRJ14U09814 → RJ14UO9814
# OK: 988.png | RAW | RJ45 CJ 3251 → RJ45CJ3251
# OK: 989.png | RAW | PRJ14CV1685 → RJ14CV1685
# OK: 99.png | RAW | "RJ14CU4226 → RJ14CU4226
# OK: 990.png | RAW | RJ14CD7590 → RJ14CD7590
# OK: 992.png | RAW | RJ45CG0374 → RJ45CG0374
# OK: 993.png | RAW | RJ14CY3589 → RJ14CY3589
# OK: 994.png | RAW | RJ45CK5666 → RJ45CK5666
# OK: 995.png | RAW | RJ45CF2591 → RJ45CF2591
# OK: 996.png | RAW | RJ45CM6777 → RJ45CM6777
# OK: 997.png | RAW | RJ07CD4085 → RJ07CD4085
# OK: 998.png | RAW | RJ36CA7025 → RJ36CA7025
# OK: 999.png | RAW | RJ140C5325 → RJ14QC5325
# DONE. Saved: hasil_adaptive_crop_REAL-ESRGAN.csv

# %% [markdown]
# #EVALUATION RESULT (RAW REAL-ESRGAN)#

# %%
import csv, re

def clean_raw(text):
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def normalize_rj_fixedpos(raw_text):
    t = clean_raw(raw_text)
    if "RJ" in t:
        t = t[t.find("RJ"):]
    else:
        t = "RJ" + t
    t = (t + "0"*10)[:10]
    chars = list(t)
    chars[0], chars[1] = "R", "J"

    DIGIT_IDX = {2,3,6,7,8,9}
    ALPHA_IDX = {4,5}
    TO_DIGIT = {'O':'0','Q':'0','D':'0','I':'1','L':'1','Z':'2','S':'5','B':'8'}
    TO_ALPHA = {'0':'O','1':'I','2':'Z','5':'S','8':'B'}

    for i in range(10):
        if i in DIGIT_IDX and chars[i] in TO_DIGIT:
            chars[i] = TO_DIGIT[chars[i]]
        elif i in ALPHA_IDX and chars[i] in TO_ALPHA:
            chars[i] = TO_ALPHA[chars[i]]
    return "".join(chars)

def levenshtein(a, b):
    if a == b: return 0
    if not a: return len(b)
    if not b: return len(a)
    prev = list(range(len(b)+1))
    for i, ca in enumerate(a, 1):
        cur = [i]
        for j, cb in enumerate(b, 1):
            cur.append(min(cur[j-1]+1, prev[j]+1, prev[j-1]+(ca!=cb)))
        prev = cur
    return prev[-1]

# --- LOAD GT ---
GT_PATH = r"ground truth.txt"   # ganti jika perlu
gt = {}
with open(GT_PATH, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        if "\t" in line:
            img, plate = line.strip().split("\t")
            fname = img.split("/")[-1]
            gt[fname] = normalize_rj_fixedpos(plate)

# --- LOAD CSV ---
CSV_PATH = r"Result_crop_REAL-ESRGAN.csv"  # <-- CSV hasil pipeline
rows = []
with open(CSV_PATH, newline="", encoding="utf-8", errors="replace") as f:
    rows = list(csv.DictReader(f))

total = unreadable = readable = correct_e2e = 0
recog_total = recog_correct = 0
char_sum = 0.0

for r in rows:
    fname = r.get("File_Name","").strip()
    if fname not in gt: continue
    total += 1

    raw = r.get("Raw_OCR","").strip()
    conf_raw = r.get("Conf_0to1","").strip()
    try:
        conf = float(conf_raw)
    except:
        conf = 1.0 if raw != "" else 0.0

    if raw == "" or conf == 0.0:
        unreadable += 1
        continue

    readable += 1
    recog_total += 1

    pred = normalize_rj_fixedpos(r.get("Final_Plate",""))
    gt_plate = gt[fname]

    if pred == gt_plate:
        recog_correct += 1
        correct_e2e += 1

    dist = levenshtein(pred, gt_plate)
    char_sum += (1 - dist/10)

print("\n=== EVALUATION RESULT (RAW REAL-ESRGAN) ===")
print("Total samples       :", total)
print("Unreadable (OCR=∅)  :", unreadable)
print("Readable            :", readable)
print("----------------------------------")
print(f"Readability Rate          : {readable/total*100:.2f}%")
print(f"End-to-End Exact Accuracy : {correct_e2e/total*100:.2f}%")
if recog_total:
    print(f"Recognition Exact Acc     : {recog_correct/recog_total*100:.2f}%")
    print(f"Average Character Acc     : {char_sum/recog_total*100:.2f}%")
# Out:
# === EVALUATION RESULT (RAW REAL-ESRGAN) ===
# Total samples       : 750
# Unreadable (OCR=∅)  : 1
# Readable            : 749
# ----------------------------------
# Readability Rate          : 99.87%
# End-to-End Exact Accuracy : 84.67%
# Recognition Exact Acc     : 84.78%
# Average Character Acc     : 96.17%

# %% [markdown]
# ##

# %% [markdown]
# #PaddleOCR Adaptive Enhancement#

# %%
import os
import csv
import re
import cv2
from paddleocr import PaddleOCR

# ============================================================
# 0) CONFIG
# ============================================================
INPUT_FOLDER = r"D:\Uniska\~Disertasi\~Projek Jurnal\sr_crop-RJ"   # <-- ganti
OUT_CSV      = r"result_adaptive_initial.csv"                      # <-- output untuk Adaptive (initial)

# ============================================================
# 1) OCR INIT
# ============================================================
ocr = PaddleOCR(
    use_angle_cls=True,
    lang='en',
    show_log=False,
    det_db_thresh=0.3
)

# ============================================================
# 2) BASIC HELPERS
# ============================================================
def clean_raw(text: str) -> str:
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def pick_best_line(result):
    """
    Ambil 1 baris terbaik berdasarkan confidence.
    Robust: aman untuk None / [] / [[...]].
    """
    if result is None:
        return "", 0.0
    if not isinstance(result, list) or len(result) == 0:
        return "", 0.0

    # PaddleOCR umum: result = [ [line1, line2, ...] ]
    lines = result[0] if (len(result) == 1 and isinstance(result[0], list)) else result
    if not lines:
        return "", 0.0

    best_text, best_conf = "", 0.0
    for line in lines:
        try:
            txt = line[1][0]
            conf = float(line[1][1])
        except Exception:
            continue
        if txt and conf > best_conf:
            best_text, best_conf = str(txt), conf
    return best_text, best_conf

# ============================================================
# 3) VARIANTS (Adaptive Enhancement) -> untuk Adaptive (initial)
#    (tetap pakai varian ringan: RAW, CLAHE-light, SR2x+CLAHE-light)
# ============================================================
def clahe_light(bgr, clip=2.0, grid=(8, 8)):
    gray = cv2.cvtColor(bgr, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=clip, tileGridSize=grid)
    enhanced = clahe.apply(gray)
    return cv2.cvtColor(enhanced, cv2.COLOR_GRAY2BGR)

def sr2x_bicubic(bgr):
    h, w = bgr.shape[:2]
    return cv2.resize(bgr, (w * 2, h * 2), interpolation=cv2.INTER_CUBIC)

def sr2x_plus_clahe(bgr, clip=2.0, grid=(8, 8)):
    up = sr2x_bicubic(bgr)
    return clahe_light(up, clip=clip, grid=grid)

def make_variants(img):
    return [
        ("RAW", img),
        ("CLAHE-light", clahe_light(img, clip=2.0, grid=(8, 8))),
        ("SR2x+CLAHE-light", sr2x_plus_clahe(img, clip=2.0, grid=(8, 8))),
    ]

# ============================================================
# 4) NORMALIZATION (Optional)
#    Untuk Adaptive (initial) di paper biasanya:
#    - hanya pilih hasil OCR tertinggi (confidence-based)
#    - boleh simpan RAW_OCR cleaned untuk evaluasi
#
#    Jika evaluasi Anda butuh format fixed 10 (RJ...), Anda bisa aktifkan
#    normalize_rj_fixedpos() di bawah. Kalau tidak perlu, set USE_NORMALIZE=False.
# ============================================================
USE_NORMALIZE = True  # <-- set False jika mau pure raw OCR (tanpa normalisasi)

def normalize_rj_fixedpos(raw_text: str) -> str:
    """
    Versi ringan (tanpa plate-aware scoring/gating):
    - anchor RJ
    - enforce length 10
    - casting per slot (digit/alpha)
    - pasangan [4-5] OC/CO/0C/C0 -> QC/CQ (ini masih "normalisasi", bukan selection)
    """
    t0 = clean_raw(raw_text)

    if "RJ" in t0:
        t = t0[t0.find("RJ"):]
    else:
        t = "RJ" + t0

    if len(t) < 10:
        t = t.ljust(10, "0")
    else:
        t = t[:10]

    chars = list(t)
    chars[0], chars[1] = "R", "J"

    digit_idx = {2, 3, 6, 7, 8, 9}
    alpha_idx = {4, 5}

    to_digit = {"O": "0", "Q": "0", "D": "0", "I": "1", "L": "1", "Z": "2", "S": "5", "B": "8"}
    to_alpha = {"0": "O", "1": "I", "2": "Z", "5": "S", "8": "B"}

    for i in range(10):
        c = chars[i]
        if i in digit_idx and c in to_digit:
            chars[i] = to_digit[c]
        elif i in alpha_idx and c in to_alpha:
            chars[i] = to_alpha[c]

    pair = chars[4] + chars[5]
    pair_map = {"OC": ("Q", "C"), "CO": ("C", "Q"), "0C": ("Q", "C"), "C0": ("C", "Q")}
    if pair in pair_map:
        chars[4], chars[5] = pair_map[pair]

    return "".join(chars)

# ============================================================
# 5) ADAPTIVE (INITIAL) SELECTION
#    Pilih kandidat terbaik hanya berdasarkan CONFIDENCE OCR
#    (tanpa plate-aware scoring, tanpa gating antar-variant).
# ============================================================
def select_best_initial_confidence(variant_results):
    """
    variant_results: list of (variant_name, paddle_result)
    Return dict best or None
    """
    best = None
    for vname, pres in variant_results:
        raw_text, conf = pick_best_line(pres)
        if not raw_text:
            continue

        final_text = normalize_rj_fixedpos(raw_text) if USE_NORMALIZE else clean_raw(raw_text)

        cand = {
            "variant": vname,
            "raw_text": raw_text,
            "final_plate": final_text,
            "conf": float(conf),
        }

        if (best is None) or (cand["conf"] > best["conf"]):
            best = cand

    return best

# ============================================================
# 6) MAIN LOOP -> CSV
# ============================================================
image_files = sorted([
    f for f in os.listdir(INPUT_FOLDER)
    if f.lower().endswith((".png", ".jpg", ".jpeg"))
])

with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow([
        "File_Name", "Variant", "Raw_OCR", "Final_Text", "Conf_0to1"
    ])

    for fn in image_files:
        img_path = os.path.join(INPUT_FOLDER, fn)
        img = cv2.imread(img_path)

        if img is None:
            w.writerow([fn, "", "", "", 0])
            print("BAD IMAGE:", fn)
            continue

        variant_results = []
        for vname, vimg in make_variants(img):
            try:
                pres = ocr.ocr(vimg, cls=True)
            except Exception:
                pres = None
            variant_results.append((vname, pres))

        best = select_best_initial_confidence(variant_results)

        if best is None:
            w.writerow([fn, "", "", "", 0])
            print("NO TEXT:", fn)
        else:
            w.writerow([
                fn,
                best["variant"],
                best["raw_text"],
                best["final_plate"],
                round(best["conf"], 6),
            ])
            print(f"OK: {fn} | {best['variant']} | {best['raw_text']} → {best['final_plate']}")

print("DONE. Saved:", OUT_CSV)
# Out:
# OK: 100.png | SR2x+CLAHE-light | RJ45CK4748 → RJ45CK4748
# OK: 1000.png | SR2x+CLAHE-light | RJ14CG6581 → RJ14CG6581
# OK: 1001.png | CLAHE-light | RJ14CK8305 → RJ14CK8305
# OK: 101.png | CLAHE-light | RJ14CZ0391 → RJ14CZ0391
# OK: 102.png | SR2x+CLAHE-light | RJ45CH4583 → RJ45CH4583
# OK: 103.png | SR2x+CLAHE-light | FRJ45CJ9969 → RJ45CJ9969
# OK: 104.png | SR2x+CLAHE-light | RJ14LC6763 → RJ14LC6763
# OK: 105.png | SR2x+CLAHE-light | RJ31CF7171 → RJ31CF7171
# OK: 106.png | SR2x+CLAHE-light | RJ08CA6767 → RJ08CA6767
# OK: 107.png | SR2x+CLAHE-light | RJ45CN9693 → RJ45CN9693
# OK: 108.png | SR2x+CLAHE-light | RJ45CK7827 → RJ45CK7827
# OK: 109.png | RAW | RJ45CQ1702 → RJ45CQ1702
# OK: 111.png | RAW | RJ14CF 9928 → RJ14CF9928
# OK: 112.png | SR2x+CLAHE-light | RJ45C09137 → RJ45CQ9137
# OK: 113.png | CLAHE-light | RJ14CY6039 → RJ14CY6039
# OK: 114.png | RAW | RJ14 CG 9094 → RJ14CG9094
# OK: 115.png | RAW | FRJ14VC0628 → RJ14VC0628
# OK: 116.png | SR2x+CLAHE-light | RJ14CD4810 → RJ14CD4810
# OK: 118.png | SR2x+CLAHE-light | RJ14XC6909 → RJ14XC6909
# OK: 119.png | SR2x+CLAHE-light | RJ01CB7236 → RJ01CB7236
# OK: 120.png | RAW | RJ45CN2934 → RJ45CN2934
# OK: 122.png | CLAHE-light | FRJ45CU0611 → RJ45CU0611
# OK: 123.png | RAW | FRJ14079165 → RJ14O79165
# OK: 124.png | SR2x+CLAHE-light | PRJ45CJ5888 → RJ45CJ5888
# OK: 125.png | RAW | RJ45CV3753 → RJ45CV3753
# OK: 126.png | SR2x+CLAHE-light | FRJ140C9780 → RJ14QC9780
# OK: 127.png | RAW | RJ14NC3966 → RJ14NC3966
# OK: 128.png | RAW | RJ45CU9366 → RJ45CU9366
# OK: 129.png | SR2x+CLAHE-light | FRJ45CV2733 → RJ45CV2733
# OK: 130.png | SR2x+CLAHE-light | FRJ31CA9891 → RJ31CA9891
# OK: 132.png | CLAHE-light | RJ45CJ2575 → RJ45CJ2575
# OK: 133.png | SR2x+CLAHE-light | FRJ06U86992 → RJ06UB6992
# OK: 134.png | SR2x+CLAHE-light | FRJ14CW2974 → RJ14CW2974
# OK: 135.png | SR2x+CLAHE-light | RJ14CJ6981 → RJ14CJ6981
# OK: 136.png | RAW | RJ14UF3370 → RJ14UF3370
# OK: 138.png | RAW | RJ02CC3751 → RJ02CC3751
# OK: 139.png | RAW | RJ14 CK 8761 → RJ14CK8761
# OK: 140.png | SR2x+CLAHE-light | RJ14UG6680 → RJ14UG6680
# OK: 141.png | CLAHE-light | RJ14CN6911 → RJ14CN6911
# OK: 142.png | CLAHE-light | RJ14 CF 3202 → RJ14CF3202
# OK: 143.png | CLAHE-light | RJ14CF6174 → RJ14CF6174
# OK: 144.png | CLAHE-light | RJ45CE6928 → RJ45CE6928
# OK: 145.png | CLAHE-light | RJ14CQ9643 → RJ14CQ9643
# OK: 147.png | SR2x+CLAHE-light | RJ148C8504 → RJ14BC8504
# OK: 148.png | SR2x+CLAHE-light | RJI4CR9968 → RJ14CR9968
# OK: 149.png | SR2x+CLAHE-light | FRJ45CJ4172 → RJ45CJ4172
# OK: 151.png | CLAHE-light | RJ45CE 9024 → RJ45CE9024
# OK: 152.png | RAW | FRJ14CU9485 → RJ14CU9485
# OK: 153.png | SR2x+CLAHE-light | FRJ45CH3914 → RJ45CH3914
# OK: 154.png | SR2x+CLAHE-light | RJ52.CA.1525 → RJ52CA1525
# OK: 155.png | CLAHE-light | FRJ14UE5266 → RJ14UE5266
# OK: 156.png | SR2x+CLAHE-light | RJ14 CD7282 → RJ14CD7282
# OK: 157.png | SR2x+CLAHE-light | RJ149C0607 → RJ149C0607
# OK: 158.png | RAW | RJ14CF4576 → RJ14CF4576
# OK: 159.png | SR2x+CLAHE-light | IND → RJ1NDO0000
# OK: 160.png | SR2x+CLAHE-light | RJ45CE2359 → RJ45CE2359
# OK: 161.png | SR2x+CLAHE-light | RJ14CD9828 → RJ14CD9828
# OK: 162.png | RAW | RJ14AC3406 → RJ14AC3406
# OK: 163.png | SR2x+CLAHE-light | IND → RJ1NDO0000
# OK: 164.png | SR2x+CLAHE-light | RJ140C7366 → RJ14QC7366
# OK: 165.png | SR2x+CLAHE-light | RJ27CG3450 → RJ27CG3450
# OK: 166.png | SR2x+CLAHE-light | RJ14LC6806 → RJ14LC6806
# OK: 167.png | CLAHE-light | RJ45CE9326 → RJ45CE9326
# OK: 168.png | RAW | RJ14CJ7361 → RJ14CJ7361
# OK: 169.png | RAW | RJ140C9911 → RJ14QC9911
# OK: 170.png | RAW | RJ45CM6548 → RJ45CM6548
# OK: 212.png | RAW | RJ14CD6355 → RJ14CD6355
# OK: 213.png | RAW | RJ14CJ4269 → RJ14CJ4269
# OK: 214.png | CLAHE-light | RJ14CY1134 → RJ14CY1134
# OK: 215.png | RAW | ERJ45CT2231 → RJ45CT2231
# OK: 216.png | RAW | RJ45CM9091 → RJ45CM9091
# OK: 217.png | SR2x+CLAHE-light | RJ14TF0294 → RJ14TF0294
# OK: 218.png | SR2x+CLAHE-light | RJ45CL7067 → RJ45CL7067
# OK: 219.png | RAW | RJ45CR6853 → RJ45CR6853
# OK: 220.png | SR2x+CLAHE-light | RJ14CQ3553 → RJ14CQ3553
# OK: 221.png | SR2x+CLAHE-light | RJ14CB0709 → RJ14CB0709
# OK: 222.png | SR2x+CLAHE-light | RJ14CQ0560 → RJ14CQ0560
# OK: 223.png | RAW | RJ14ZC4023 → RJ14ZC4023
# OK: 224.png | SR2x+CLAHE-light | RJ14VC4981 → RJ14VC4981
# OK: 225.png | SR2x+CLAHE-light | RJ45C02581 → RJ45CQ2581
# OK: 226.png | CLAHE-light | 1385 → RJ13BS0000
# OK: 227.png | CLAHE-light | RJ14 CL4477 → RJ14CL4477
# OK: 228.png | CLAHE-light | RJ01CB9294 → RJ01CB9294
# OK: 229.png | CLAHE-light | RJ14CV1286 → RJ14CV1286
# OK: 230.png | RAW | RJ45CT4349 → RJ45CT4349
# OK: 231.png | SR2x+CLAHE-light | RJ14CX9236 → RJ14CX9236
# OK: 232.png | SR2x+CLAHE-light | RJ14VC6735 → RJ14VC6735
# OK: 233.png | SR2x+CLAHE-light | RJ01CE3953 → RJ01CE3953
# OK: 234.png | SR2x+CLAHE-light | RJ14YC3009 → RJ14YC3009
# OK: 235.png | CLAHE-light | RJ14CN6419 → RJ14CN6419
# OK: 236.png | RAW | RJ14CZ5492 → RJ14CZ5492
# OK: 237.png | RAW | 5315 → RJ53IS0000
# OK: 238.png | RAW | RJ14CY9553 → RJ14CY9553
# OK: 239.png | SR2x+CLAHE-light | RJ14C03981 → RJ14CQ3981
# OK: 240.png | RAW | RJ14QC9673 → RJ14QC9673
# OK: 241.png | RAW | RJ14U02000 → RJ14UO2000
# OK: 242.png | SR2x+CLAHE-light | RJ45CK1303 → RJ45CK1303
# OK: 243.png | SR2x+CLAHE-light | RJ45CL6966 → RJ45CL6966
# OK: 244.png | CLAHE-light | RJ14VC3804 → RJ14VC3804
# OK: 245.png | RAW | RJ45CT4296 → RJ45CT4296
# OK: 246.png | CLAHE-light | RJ14UH7714 → RJ14UH7714
# OK: 247.png | SR2x+CLAHE-light | IND → RJ1NDO0000
# OK: 248.png | RAW | RJ45CJ3253 → RJ45CJ3253
# OK: 249.png | SR2x+CLAHE-light | RJ14CP6854 → RJ14CP6854
# OK: 250.png | SR2x+CLAHE-light | RJ45CL3942 → RJ45CL3942
# OK: 251.png | CLAHE-light | ~RJ45CH2013 → RJ45CH2013
# OK: 252.png | SR2x+CLAHE-light | RJ45CN0760 → RJ45CN0760
# OK: 253.png | CLAHE-light | RJ14CF9305 → RJ14CF9305
# OK: 300.png | RAW | RJ20C67278 → RJ20C67278
# OK: 301.png | RAW | RJ14CW7787 → RJ14CW7787
# OK: 302.png | RAW | RJ27CG1234 → RJ27CG1234
# OK: 303.png | CLAHE-light | RJ45CN0340 → RJ45CN0340
# OK: 304.png | SR2x+CLAHE-light | RJ23CC3290 → RJ23CC3290
# OK: 305.png | RAW | RJ14 CG 1753 → RJ14CG1753
# OK: 306.png | SR2x+CLAHE-light | IND → RJ1NDO0000
# OK: 307.png | RAW | RJ45CE6928 → RJ45CE6928
# OK: 308.png | SR2x+CLAHE-light | FRJ23CC3290 → RJ23CC3290
# OK: 309.png | RAW | RJ14TE9879 → RJ14TE9879
# OK: 310.png | RAW | RJ45CE6928 → RJ45CE6928
# OK: 311.png | CLAHE-light | RJ45CF4478 → RJ45CF4478
# OK: 312.png | SR2x+CLAHE-light | RJ02CC9572 → RJ02CC9572
# OK: 313.png | SR2x+CLAHE-light | RJ4UF7821 → RJ4UF78210
# OK: 314.png | SR2x+CLAHE-light | FRJ45CM6663 → RJ45CM6663
# OK: 316.png | SR2x+CLAHE-light | RJ23CC9808 → RJ23CC9808
# OK: 317.png | RAW | RJ14CR8650 → RJ14CR8650
# OK: 318.png | CLAHE-light | RJ14ZC2898 → RJ14ZC2898
# OK: 319.png | CLAHE-light | RJ14ZC2898 → RJ14ZC2898
# OK: 320.png | SR2x+CLAHE-light | RJ14CM5958 → RJ14CM5958
# OK: 322.png | SR2x+CLAHE-light | RJ14XC9775 → RJ14XC9775
# OK: 324.png | RAW | ~RJ47UB0221 → RJ47UB0221
# OK: 325.png | RAW | RJ14CL5038 → RJ14CL5038
# OK: 326.png | SR2x+CLAHE-light | RJ45CT4953 → RJ45CT4953
# OK: 327.png | CLAHE-light | RJ14CY6163 → RJ14CY6163
# OK: 329.png | RAW | RJ14XC5078 → RJ14XC5078
# OK: 330.png | CLAHE-light | RJ45CJ4569 → RJ45CJ4569
# OK: 331.png | RAW | RJO7UC4983 → RJ07UC4983
# OK: 334.png | RAW | RJ45CM1278 → RJ45CM1278
# OK: 336.png | CLAHE-light | RJ45CH5898 → RJ45CH5898
# OK: 337.png | SR2x+CLAHE-light | RJ45CH5898 → RJ45CH5898
# OK: 338.png | RAW | RJ14CN9474 → RJ14CN9474
# OK: 339.png | SR2x+CLAHE-light | RJ14CA7406 → RJ14CA7406
# OK: 340.png | RAW | RJ49CA3195 → RJ49CA3195
# OK: 342.png | SR2x+CLAHE-light | RJ45CU4154 → RJ45CU4154
# OK: 343.png | CLAHE-light | RJ13CB4334 → RJ13CB4334
# OK: 346.png | SR2x+CLAHE-light | RJ14UF3853 → RJ14UF3853
# OK: 347.png | SR2x+CLAHE-light | RJ14 CE9566 → RJ14CE9566
# OK: 348.png | RAW | RJ45CJ4912 → RJ45CJ4912
# OK: 349.png | RAW | RJ14CY2297 → RJ14CY2297
# OK: 350.png | CLAHE-light | RJ14TB.3340 → RJ14TB3340
# OK: 351.png | SR2x+CLAHE-light | RJ14UE2634 → RJ14UE2634
# OK: 352.png | SR2x+CLAHE-light | RJ14LC7020 → RJ14LC7020
# OK: 353.png | SR2x+CLAHE-light | RJ14TB1532 → RJ14TB1532
# OK: 354.png | RAW | RJ14TB1532 → RJ14TB1532
# OK: 355.png | SR2x+CLAHE-light | RJ14C06834 → RJ14CQ6834
# OK: 356.png | SR2x+CLAHE-light | RJ140C2466 → RJ14QC2466
# OK: 357.png | SR2x+CLAHE-light | RJ-21-UA-6951 → RJ21UA6951
# OK: 358.png | SR2x+CLAHE-light | RJ42CA2609 → RJ42CA2609
# OK: 359.png | SR2x+CLAHE-light | RJ14T00050 → RJ14TO0050
# OK: 360.png | SR2x+CLAHE-light | RJ14UG9174 → RJ14UG9174
# OK: 361.png | CLAHE-light | RJ21CB9889 → RJ21CB9889
# OK: 362.png | CLAHE-light | RJ45CP2856 → RJ45CP2856
# OK: 364.png | CLAHE-light | RJ20CF1019 → RJ20CF1019
# OK: 365.png | CLAHE-light | RJ14CN3290 → RJ14CN3290
# OK: 366.png | RAW | RJ18TA2689 → RJ18TA2689
# OK: 367.png | RAW | RJ41UA2827 → RJ41UA2827
# OK: 368.png | SR2x+CLAHE-light | RJ47TA0050 → RJ47TA0050
# OK: 369.png | RAW | RJ140C8708 → RJ14QC8708
# OK: 370.png | CLAHE-light | RJ14TB9803 → RJ14TB9803
# OK: 371.png | CLAHE-light | RJ14TA6551 → RJ14TA6551
# OK: 372.png | SR2x+CLAHE-light | RJ14YC7926 → RJ14YC7926
# OK: 373.png | SR2x+CLAHE-light | RJ14TE2837 → RJ14TE2837
# OK: 374.png | SR2x+CLAHE-light | RJ14TD5707 → RJ14TD5707
# OK: 375.png | SR2x+CLAHE-light | RJ19TA-0994 → RJ19TA0994
# OK: 377.png | RAW | RJ14CY7851 → RJ14CY7851
# OK: 379.png | CLAHE-light | RJ45CQ4036 → RJ45CQ4036
# OK: 380.png | SR2x+CLAHE-light | RJ14CK0008 → RJ14CK0008
# OK: 381.png | CLAHE-light | RJ14CT4026 → RJ14CT4026
# OK: 382.png | CLAHE-light | RJ14UD5383 → RJ14UD5383
# OK: 383.png | SR2x+CLAHE-light | RJ40CA1097 → RJ40CA1097
# OK: 386.png | SR2x+CLAHE-light | RJ45CE4246 → RJ45CE4246
# OK: 387.png | CLAHE-light | RJ45CT1012 → RJ45CT1012
# OK: 388.png | CLAHE-light | RJ14CR5019 → RJ14CR5019
# OK: 389.png | SR2x+CLAHE-light | RJ23UB6081 → RJ23UB6081
# OK: 390.png | SR2x+CLAHE-light | RJ02CC6621 → RJ02CC6621
# OK: 391.png | SR2x+CLAHE-light | RJ21UG0044 → RJ21UG0044
# OK: 392.png | RAW | RJ14UF1632 → RJ14UF1632
# OK: 393.png | CLAHE-light | RJ45CT9496 → RJ45CT9496
# OK: 394.png | SR2x+CLAHE-light | RJ18CD2193 → RJ18CD2193
# OK: 395.png | SR2x+CLAHE-light | RJ02CC 4642 → RJ02CC4642
# OK: 396.png | CLAHE-light | RJ14UG8209 → RJ14UG8209
# OK: 397.png | RAW | ~RJ45CP5704 → RJ45CP5704
# OK: 398.png | SR2x+CLAHE-light | RJ45CA2953 → RJ45CA2953
# OK: 399.png | RAW | RJ45CR2576 → RJ45CR2576
# OK: 400.png | CLAHE-light | RJ13CB6214 → RJ13CB6214
# OK: 401.png | SR2x+CLAHE-light | RJ4CL1162 → RJ4CLI1620
# OK: 402.png | CLAHE-light | RJ14 ZC2864 → RJ14ZC2864
# OK: 403.png | SR2x+CLAHE-light | RJ14CU5325 → RJ14CU5325
# OK: 404.png | SR2x+CLAHE-light | RJ14UH7046 → RJ14UH7046
# OK: 405.png | RAW | RJ14TD0733 → RJ14TD0733
# OK: 406.png | SR2x+CLAHE-light | RJ45CS0617 → RJ45CS0617
# OK: 407.png | RAW | RJ14TB4095 → RJ14TB4095
# OK: 408.png | RAW | RJ45CT6689 → RJ45CT6689
# OK: 409.png | RAW | RJ14TB1265 → RJ14TB1265
# OK: 410.png | RAW | RJ14TB7738 → RJ14TB7738
# OK: 411.png | SR2x+CLAHE-light | RJ14TD0908 → RJ14TD0908
# OK: 412.png | CLAHE-light | RJ14TD4148 → RJ14TD4148
# OK: 413.png | RAW | RJ14UD8337 → RJ14UD8337
# OK: 414.png | SR2x+CLAHE-light | RJ06UA9743 → RJ06UA9743
# OK: 415.png | RAW | FRJ14TD7268 → RJ14TD7268
# OK: 416.png | RAW | RJ47TA0568 → RJ47TA0568
# OK: 417.png | RAW | RJ14TB7210 → RJ14TB7210
# OK: 418.png | CLAHE-light | RJ18CD3382 → RJ18CD3382
# OK: 419.png | CLAHE-light | RJ23UA4493 → RJ23UA4493
# OK: 420.png | CLAHE-light | RJ14UH4591 → RJ14UH4591
# OK: 421.png | SR2x+CLAHE-light | RJ14T89315 → RJ14TB9315
# OK: 423.png | SR2x+CLAHE-light | RJ22UB1551 → RJ22UB1551
# OK: 425.png | SR2x+CLAHE-light | RJ45CT3790 → RJ45CT3790
# OK: 426.png | CLAHE-light | RJ45CT1885 → RJ45CT1885
# OK: 427.png | SR2x+CLAHE-light | RJ45CT3790 → RJ45CT3790
# OK: 428.png | SR2x+CLAHE-light | RJ07CD5141 → RJ07CD5141
# OK: 429.png | RAW | RJ45CE2714 → RJ45CE2714
# OK: 430.png | SR2x+CLAHE-light | RJ06CC2305 → RJ06CC2305
# OK: 434.png | CLAHE-light | RJ14 CA9656 → RJ14CA9656
# OK: 435.png | SR2x+CLAHE-light | RJ14VC5878 → RJ14VC5878
# OK: 436.png | SR2x+CLAHE-light | RJ14CN2137 → RJ14CN2137
# OK: 437.png | CLAHE-light | RJ45CU8299 → RJ45CU8299
# OK: 438.png | RAW | RJ14CT8400 → RJ14CT8400
# OK: 440.png | CLAHE-light | RJ14WC6764 → RJ14WC6764
# OK: 441.png | SR2x+CLAHE-light | RJ14NC3343 → RJ14NC3343
# OK: 442.png | RAW | RJ45CD8518 → RJ45CD8518
# OK: 443.png | CLAHE-light | RJ14UJ0242 → RJ14UJ0242
# OK: 444.png | RAW | RJ45CD2364 → RJ45CD2364
# OK: 499.png | SR2x+CLAHE-light | RJ14NC8821 → RJ14NC8821
# OK: 500.png | RAW | RJ45CL8141 → RJ45CL8141
# OK: 501.png | CLAHE-light | RJ45CP5152 → RJ45CP5152
# OK: 504.png | SR2x+CLAHE-light | RJ45CJ6596 → RJ45CJ6596
# OK: 505.png | RAW | RJ45CJ4318 → RJ45CJ4318
# OK: 506.png | RAW | RJ14CZ8472 → RJ14CZ8472
# OK: 507.png | SR2x+CLAHE-light | RJ45CE4794 → RJ45CE4794
# OK: 510.png | CLAHE-light | RJ45CN8319 → RJ45CN8319
# OK: 511.png | SR2x+CLAHE-light | RJ14CX3214 → RJ14CX3214
# OK: 513.png | RAW | RJ01CB9722 → RJ01CB9722
# OK: 514.png | SR2x+CLAHE-light | RJ14CM0432 → RJ14CM0432
# OK: 515.png | RAW | RJ19CE6441 → RJ19CE6441
# OK: 516.png | RAW | RJ14YC6644 → RJ14YC6644
# OK: 517.png | CLAHE-light | RJ45CS7817 → RJ45CS7817
# OK: 519.png | RAW | RJ45CL7767 → RJ45CL7767
# OK: 520.png | RAW | RJ14CP8198 → RJ14CP8198
# OK: 521.png | RAW | RJ14LC2878 → RJ14LC2878
# OK: 522.png | SR2x+CLAHE-light | RJ41CA2238 → RJ41CA2238
# OK: 523.png | SR2x+CLAHE-light | RJ45CH8643 → RJ45CH8643
# OK: 524.png | SR2x+CLAHE-light | RJ14CZ1668 → RJ14CZ1668
# OK: 525.png | CLAHE-light | RJ14VC4128 → RJ14VC4128
# OK: 527.png | SR2x+CLAHE-light | RJ14LC2314 → RJ14LC2314
# OK: 528.png | SR2x+CLAHE-light | RJ45CU4981 → RJ45CU4981
# OK: 529.png | RAW | RJ14VC1266 → RJ14VC1266
# OK: 530.png | RAW | RJ14CY2654 → RJ14CY2654
# OK: 531.png | SR2x+CLAHE-light | RJ14CT4301 → RJ14CT4301
# OK: 532.png | SR2x+CLAHE-light | RJ14HC9782 → RJ14HC9782
# OK: 534.png | CLAHE-light | RJ14WC9782 → RJ14WC9782
# OK: 535.png | SR2x+CLAHE-light | RJ14LC3054 → RJ14LC3054
# OK: 536.png | SR2x+CLAHE-light | RJ14AC7430 → RJ14AC7430
# OK: 537.png | CLAHE-light | RJ14YC7453 → RJ14YC7453
# OK: 538.png | RAW | RJ14C03299 → RJ14CQ3299
# OK: 539.png | RAW | RJ45CD4723 → RJ45CD4723
# OK: 540.png | RAW | RJ14CR4952 → RJ14CR4952
# OK: 541.png | SR2x+CLAHE-light | RJ03CA8807 → RJ03CA8807
# OK: 542.png | RAW | -RJ14WC0195 → RJ14WC0195
# OK: 544.png | RAW | RJ14CT9149 → RJ14CT9149
# OK: 546.png | RAW | 2566 → RJ25660000
# OK: 548.png | RAW | 2566 → RJ25660000
# OK: 549.png | CLAHE-light | RJ45CT4817 → RJ45CT4817
# OK: 551.png | RAW | RJ45CE8988 → RJ45CE8988
# OK: 554.png | RAW | RJ45CF9239 → RJ45CF9239
# OK: 555.png | RAW | RJ14XC1470 → RJ14XC1470
# OK: 556.png | RAW | RJ19CE1032 → RJ19CE1032
# OK: 557.png | SR2x+CLAHE-light | RJ14WC2203 → RJ14WC2203
# OK: 558.png | SR2x+CLAHE-light | RJ45CS5230 → RJ45CS5230
# OK: 559.png | SR2x+CLAHE-light | RJ45CK0487 → RJ45CK0487
# OK: 560.png | RAW | 7291 → RJ729I0000
# OK: 561.png | CLAHE-light | RJ14CU8301 → RJ14CU8301
# OK: 563.png | RAW | RJ40UA1802 → RJ40UA1802
# OK: 564.png | RAW | RJ14WC9272 → RJ14WC9272
# OK: 566.png | SR2x+CLAHE-light | RJ45CS0638 → RJ45CS0638
# OK: 568.png | RAW | RJ14CL8997 → RJ14CL8997
# OK: 569.png | CLAHE-light | RJ14UG9738 → RJ14UG9738
# OK: 570.png | RAW | RJ04CA7197 → RJ04CA7197
# OK: 571.png | CLAHE-light | RJ14ZC8007 → RJ14ZC8007
# OK: 573.png | CLAHE-light | RJ14UH0436 → RJ14UH0436
# OK: 574.png | SR2x+CLAHE-light | RJ14LC4620 → RJ14LC4620
# OK: 576.png | SR2x+CLAHE-light | RJ14CU5539 → RJ14CU5539
# OK: 577.png | CLAHE-light | RJ14CL4005 → RJ14CL4005
# OK: 578.png | RAW | RJ45CM4942 → RJ45CM4942
# OK: 579.png | RAW | RJ14CM6318 → RJ14CM6318
# OK: 580.png | CLAHE-light | 2095 → RJ209S0000
# OK: 581.png | CLAHE-light | RJ14XC6684 → RJ14XC6684
# OK: 582.png | RAW | RJ14AC7435 → RJ14AC7435
# OK: 583.png | RAW | RJ14CQ4852 → RJ14CQ4852
# OK: 584.png | RAW | RJ14CH5905 → RJ14CH5905
# OK: 585.png | RAW | RJ14CM1812 → RJ14CM1812
# OK: 586.png | RAW | RJ14UG4439 → RJ14UG4439
# OK: 587.png | RAW | RJ21CA5505 → RJ21CA5505
# OK: 588.png | RAW | RJ14YC4911 → RJ14YC4911
# OK: 591.png | CLAHE-light | RJ18UC0731 → RJ18UC0731
# OK: 593.png | RAW | RJ14XC5483 → RJ14XC5483
# OK: 594.png | SR2x+CLAHE-light | RJ19CC-8131 → RJ19CC8131
# OK: 595.png | RAW | RJ45CL7121 → RJ45CL7121
# OK: 597.png | SR2x+CLAHE-light | RJ14CT6932 → RJ14CT6932
# OK: 598.png | CLAHE-light | RJ14CJ2806 → RJ14CJ2806
# OK: 60.png | SR2x+CLAHE-light | RJ45CG8893 → RJ45CG8893
# OK: 600.png | RAW | RJ45 CF → RJ45CF0000
# OK: 601.png | RAW | RJ45CE6832 → RJ45CE6832
# OK: 602.png | SR2x+CLAHE-light | RJ45CP5873 → RJ45CP5873
# OK: 604.png | RAW | RJ14CV6896 → RJ14CV6896
# OK: 605.png | CLAHE-light | RJ14XC9225 → RJ14XC9225
# OK: 607.png | SR2x+CLAHE-light | RJ45CH3180 → RJ45CH3180
# OK: 609.png | RAW | RJ20CH0018 → RJ20CH0018
# OK: 61.png | SR2x+CLAHE-light | RJ44CA5682 → RJ44CA5682
# OK: 610.png | RAW | RJ45CJ0248 → RJ45CJ0248
# OK: 613.png | SR2x+CLAHE-light | RJ45CH4066 → RJ45CH4066
# OK: 614.png | SR2x+CLAHE-light | RJ19CJ4588 → RJ19CJ4588
# OK: 615.png | SR2x+CLAHE-light | RJ45CN2244 → RJ45CN2244
# OK: 616.png | RAW | RJ14WC7432 → RJ14WC7432
# OK: 617.png | CLAHE-light | RJ14UH6989 → RJ14UH6989
# OK: 62.png | RAW | RJ14LC6256 → RJ14LC6256
# OK: 620.png | RAW | RJ14YC3368 → RJ14YC3368
# OK: 622.png | SR2x+CLAHE-light | RJ14VC5005 → RJ14VC5005
# OK: 624.png | CLAHE-light | RJ14XC5212 → RJ14XC5212
# OK: 625.png | SR2x+CLAHE-light | RJ14CX9884 → RJ14CX9884
# OK: 626.png | SR2x+CLAHE-light | RJ45CH4066 → RJ45CH4066
# OK: 627.png | RAW | RJ14NC9499 → RJ14NC9499
# OK: 628.png | SR2x+CLAHE-light | RJ14NC9499 → RJ14NC9499
# OK: 629.png | SR2x+CLAHE-light | RJ45CA3146 → RJ45CA3146
# OK: 63.png | RAW | RJ45CL4097 → RJ45CL4097
# OK: 630.png | CLAHE-light | RJ02CB5825 → RJ02CB5825
# OK: 631.png | SR2x+CLAHE-light | RJ45CM2886 → RJ45CM2886
# OK: 632.png | SR2x+CLAHE-light | RJ14CP1025 → RJ14CP1025
# OK: 633.png | RAW | RJ14YC9793 → RJ14YC9793
# OK: 634.png | SR2x+CLAHE-light | RJ32CA6709 → RJ32CA6709
# OK: 635.png | SR2x+CLAHE-light | RJ03CB0994 → RJ03CB0994
# OK: 636.png | SR2x+CLAHE-light | RJ45CT6204 → RJ45CT6204
# OK: 637.png | RAW | RJ14CY6203 → RJ14CY6203
# OK: 638.png | SR2x+CLAHE-light | RJ14CP2973 → RJ14CP2973
# OK: 639.png | CLAHE-light | RJ45CM4771 → RJ45CM4771
# OK: 64.png | CLAHE-light | RJ14CY5251 → RJ14CY5251
# OK: 640.png | SR2x+CLAHE-light | RJ14XC2773 → RJ14XC2773
# OK: 641.png | SR2x+CLAHE-light | RJ14UE7301 → RJ14UE7301
# OK: 642.png | SR2x+CLAHE-light | RJ45CR5880 → RJ45CR5880
# OK: 643.png | SR2x+CLAHE-light | RJ14CT3041 → RJ14CT3041
# OK: 644.png | CLAHE-light | RJ45CU0891 → RJ45CU0891
# OK: 645.png | RAW | RJ45CJ8382 → RJ45CJ8382
# OK: 646.png | SR2x+CLAHE-light | RJ45CM2647 → RJ45CM2647
# OK: 647.png | RAW | RJ45CK8330 → RJ45CK8330
# OK: 648.png | SR2x+CLAHE-light | RJ14WC0885 → RJ14WC0885
# OK: 649.png | RAW | RJ14AC3937 → RJ14AC3937
# OK: 65.png | RAW | ERJ45C03586 → RJ45CQ3586
# OK: 650.png | RAW | FRJ01CC7603 → RJ01CC7603
# OK: 651.png | CLAHE-light | RJ20CF9232 → RJ20CF9232
# OK: 652.png | SR2x+CLAHE-light | RJ14XC1164 → RJ14XC1164
# OK: 653.png | RAW | RJ45CT4169 → RJ45CT4169
# OK: 695.png | SR2x+CLAHE-light | RJ14CJ8101 → RJ14CJ8101
# OK: 696.png | RAW | RJ14TE3395 → RJ14TE3395
# OK: 697.png | SR2x+CLAHE-light | RJ147C4090 → RJ147C4090
# OK: 698.png | RAW | RJ45CH2533 → RJ45CH2533
# OK: 699.png | SR2x+CLAHE-light | RJ14CE8805 → RJ14CE8805
# OK: 70.png | RAW | RJ14CL5486 → RJ14CL5486
# OK: 701.png | SR2x+CLAHE-light | PRJ14CX7671 → RJ14CX7671
# OK: 702.png | SR2x+CLAHE-light | RJ14CJ0773 → RJ14CJ0773
# OK: 703.png | CLAHE-light | RJ14CH6264 → RJ14CH6264
# OK: 704.png | CLAHE-light | -RJ14UC8718 → RJ14UC8718
# OK: 705.png | SR2x+CLAHE-light | FRJ45CL1273 → RJ45CL1273
# OK: 706.png | RAW | RJ45CL2546 → RJ45CL2546
# OK: 707.png | CLAHE-light | FRJ14LC4382 → RJ14LC4382
# OK: 709.png | RAW | RJ14YC8239 → RJ14YC8239
# OK: 71.png | SR2x+CLAHE-light | RJ01CB7236 → RJ01CB7236
# OK: 710.png | SR2x+CLAHE-light | FRJ45CP6844 → RJ45CP6844
# OK: 711.png | RAW | RJ45CD5708 → RJ45CD5708
# OK: 712.png | SR2x+CLAHE-light | RJ45CH2533 → RJ45CH2533
# OK: 714.png | RAW | RJ14YC7682 → RJ14YC7682
# OK: 72.png | RAW | RJ45CN2934 → RJ45CN2934
# OK: 74.png | SR2x+CLAHE-light | FRJ45CU0611 → RJ45CU0611
# OK: 75.png | SR2x+CLAHE-light | FRJ14C79165 → RJ14C79165
# OK: 76.png | RAW | RJ45CJ5888 → RJ45CJ5888
# OK: 77.png | RAW | RJ45CU5747 → RJ45CU5747
# OK: 78.png | RAW | RJ14UL4748 → RJ14UL4748
# OK: 80.png | SR2x+CLAHE-light | RJ18CE4818 → RJ18CE4818
# OK: 803.png | SR2x+CLAHE-light | RJ14CK1537 → RJ14CK1537
# OK: 804.png | RAW | -RJ45CP1891 → RJ45CP1891
# OK: 805.png | SR2x+CLAHE-light | FRJ45CS9822 → RJ45CS9822
# OK: 807.png | SR2x+CLAHE-light | FRJ47CA3067 → RJ47CA3067
# OK: 808.png | SR2x+CLAHE-light | RJ14CY0301 → RJ14CY0301
# OK: 809.png | CLAHE-light | RJ14CK5851 → RJ14CK5851
# OK: 81.png | RAW | RJ27CD0805 → RJ27CD0805
# OK: 810.png | SR2x+CLAHE-light | RJQ1-UA1712 → RJ01UA1712
# OK: 811.png | CLAHE-light | RJ14UD9814 → RJ14UD9814
# OK: 812.png | SR2x+CLAHE-light | RJ45CN3445 → RJ45CN3445
# OK: 813.png | SR2x+CLAHE-light | RJ14CT2837 → RJ14CT2837
# OK: 814.png | SR2x+CLAHE-light | RJ45CW0091 → RJ45CW0091
# OK: 815.png | SR2x+CLAHE-light | RJO2CF1365 → RJ02CF1365
# OK: 816.png | SR2x+CLAHE-light | RJ14CE1733 → RJ14CE1733
# OK: 817.png | SR2x+CLAHE-light | RJ45C09259 → RJ45CQ9259
# OK: 818.png | CLAHE-light | RJ45CK8330 → RJ45CK8330
# OK: 82.png | RAW | RJ29CA5938 → RJ29CA5938
# OK: 820.png | RAW | RJ45CJ6486 → RJ45CJ6486
# OK: 821.png | SR2x+CLAHE-light | FRJ14CZ3108 → RJ14CZ3108
# OK: 822.png | RAW | FRJ14WC9541 → RJ14WC9541
# OK: 823.png | RAW | RJ14CV4657 → RJ14CV4657
# OK: 824.png | CLAHE-light | RJ14UF8669 → RJ14UF8669
# OK: 825.png | SR2x+CLAHE-light | FRJ15UA1189 → RJ15UA1189
# OK: 826.png | RAW | RJ14UH1563 → RJ14UH1563
# OK: 827.png | RAW | RJ14CV1914 → RJ14CV1914
# OK: 828.png | SR2x+CLAHE-light | RJ07CA5369 → RJ07CA5369
# OK: 829.png | SR2x+CLAHE-light | RJ14ZC9897 → RJ14ZC9897
# OK: 83.png | RAW | RJ10CA5546 → RJ10CA5546
# OK: 830.png | CLAHE-light | RJ45CU7408 → RJ45CU7408
# OK: 831.png | SR2x+CLAHE-light | RJ14UG8787 → RJ14UG8787
# OK: 832.png | SR2x+CLAHE-light | FRJ40CA7299 → RJ40CA7299
# OK: 833.png | SR2x+CLAHE-light | RJ14CZ8986 → RJ14CZ8986
# OK: 834.png | RAW | RJ14CZ5755 → RJ14CZ5755
# OK: 835.png | RAW | ~RJ14CA9687 → RJ14CA9687
# OK: 836.png | SR2x+CLAHE-light | RJ45CF1633 → RJ45CF1633
# OK: 837.png | RAW | RJ45CV6466 → RJ45CV6466
# OK: 838.png | SR2x+CLAHE-light | RJ45CV6605 → RJ45CV6605
# OK: 839.png | SR2x+CLAHE-light | RJ45CN0022 → RJ45CN0022
# OK: 84.png | RAW | RJ44CA2231 → RJ44CA2231
# OK: 840.png | SR2x+CLAHE-light | RJ05CC0003 → RJ05CC0003
# OK: 841.png | SR2x+CLAHE-light | RJ14CW9269 → RJ14CW9269
# OK: 842.png | CLAHE-light | RJ14CU5690 → RJ14CU5690
# OK: 843.png | CLAHE-light | RJ45CG7702 → RJ45CG7702
# OK: 844.png | RAW | RJ14ZC7793 → RJ14ZC7793
# OK: 845.png | SR2x+CLAHE-light | RJ14UE5553 → RJ14UE5553
# OK: 846.png | RAW | RJ45CL2546 → RJ45CL2546
# OK: 847.png | SR2x+CLAHE-light | RJ14CL0535 → RJ14CL0535
# OK: 848.png | RAW | FRJ45C07703 → RJ45CQ7703
# OK: 849.png | RAW | RJ45CS4737 → RJ45CS4737
# OK: 85.png | RAW | RJ45CL4748 → RJ45CL4748
# OK: 850.png | SR2x+CLAHE-light | RJ45CV1494 → RJ45CV1494
# OK: 851.png | RAW | RJ14CX3188 → RJ14CX3188
# OK: 852.png | SR2x+CLAHE-light | RJ14CC0979 → RJ14CC0979
# OK: 853.png | SR2x+CLAHE-light | RJ45CP6364 → RJ45CP6364
# OK: 854.png | SR2x+CLAHE-light | RJ14WC1303 → RJ14WC1303
# OK: 856.png | RAW | RJ45CP8366 → RJ45CP8366
# OK: 857.png | RAW | RJ14CQ3372 → RJ14CQ3372
# OK: 858.png | SR2x+CLAHE-light | RJ147C0010 → RJ147C0010
# OK: 859.png | RAW | RJ14CT7262 → RJ14CT7262
# OK: 86.png | RAW | RJ45CM6898 → RJ45CM6898
# OK: 861.png | RAW | RJ14TE0516 → RJ14TE0516
# OK: 862.png | RAW | RJ45CU1237 → RJ45CU1237
# OK: 863.png | SR2x+CLAHE-light | RJ29CA5938 → RJ29CA5938
# OK: 864.png | RAW | RJ14CE3763 → RJ14CE3763
# OK: 865.png | SR2x+CLAHE-light | RJ14CZ6795 → RJ14CZ6795
# OK: 866.png | RAW | RJ14UH0270 → RJ14UH0270
# OK: 867.png | RAW | RJ45CH1213 → RJ45CH1213
# OK: 868.png | RAW | RJ45CU1897 → RJ45CU1897
# OK: 869.png | RAW | RJ29CA7848 → RJ29CA7848
# OK: 87.png | RAW | RJ45CU3690 → RJ45CU3690
# OK: 870.png | SR2x+CLAHE-light | RJ45CY0109 → RJ45CY0109
# OK: 871.png | SR2x+CLAHE-light | RJ14CC8393 → RJ14CC8393
# OK: 872.png | SR2x+CLAHE-light | RJi3CA3418 → RJ13CA3418
# OK: 873.png | SR2x+CLAHE-light | RJ14TD074 → RJ14TD0740
# OK: 874.png | CLAHE-light | RJ14CY5022 → RJ14CY5022
# OK: 875.png | RAW | RJ14CB6100 → RJ14CB6100
# OK: 876.png | SR2x+CLAHE-light | RJ21CB 3598 → RJ21CB3598
# OK: 877.png | SR2x+CLAHE-light | RJ45CE3482 → RJ45CE3482
# OK: 878.png | RAW | RJ14UJ0992 → RJ14UJ0992
# OK: 879.png | RAW | FRJ08CA6767 → RJ08CA6767
# OK: 88.png | RAW | RJ45CL4097 → RJ45CL4097
# OK: 880.png | RAW | -RJ45CN9693 → RJ45CN9693
# OK: 881.png | CLAHE-light | RJ140C2447 → RJ14QC2447
# OK: 882.png | RAW | RJ45CJ1568 → RJ45CJ1568
# OK: 883.png | SR2x+CLAHE-light | RJ45CU2324 → RJ45CU2324
# OK: 884.png | RAW | RJ20CD2031 → RJ20CD2031
# OK: 885.png | SR2x+CLAHE-light | PRJ14YC2665 → RJ14YC2665
# OK: 886.png | CLAHE-light | FRJ01CC1507 → RJ01CC1507
# OK: 887.png | CLAHE-light | RJ45CQ5065 → RJ45CQ5065
# OK: 888.png | CLAHE-light | FRJ14CW2950 → RJ14CW2950
# OK: 889.png | SR2x+CLAHE-light | RJ45CP1665 → RJ45CP1665
# OK: 89.png | SR2x+CLAHE-light | RJ14UG8714 → RJ14UG8714
# OK: 890.png | RAW | RJ14CV2530 → RJ14CV2530
# OK: 891.png | SR2x+CLAHE-light | RJ45CL6572 → RJ45CL6572
# OK: 892.png | RAW | FRJ45CK7827 → RJ45CK7827
# OK: 893.png | CLAHE-light | RJ14CV6829 → RJ14CV6829
# OK: 894.png | RAW | -RJ45CJ1430 → RJ45CJ1430
# OK: 895.png | CLAHE-light | RJ45CN5222 → RJ45CN5222
# OK: 896.png | RAW | RJ14LC6851 → RJ14LC6851
# OK: 898.png | SR2x+CLAHE-light | RJ14ZC6586 → RJ14ZC6586
# OK: 899.png | CLAHE-light | FRJ45CK4536 → RJ45CK4536
# OK: 90.png | SR2x+CLAHE-light | RJ23CH0055 → RJ23CH0055
# OK: 900.png | CLAHE-light | RJ45CF6777 → RJ45CF6777
# OK: 901.png | SR2x+CLAHE-light | -RJ45CK6065 → RJ45CK6065
# OK: 903.png | CLAHE-light | RJ45CS7352 → RJ45CS7352
# OK: 904.png | SR2x+CLAHE-light | RJ18CE5772 → RJ18CE5772
# OK: 905.png | RAW | RJ14CN1514 → RJ14CN1514
# OK: 906.png | CLAHE-light | PRJ25CA2829 → RJ25CA2829
# OK: 907.png | SR2x+CLAHE-light | FRJ01CD3307 → RJ01CD3307
# OK: 908.png | RAW | RJ45CR8895 → RJ45CR8895
# OK: 909.png | SR2x+CLAHE-light | RJ14UG5091 → RJ14UG5091
# OK: 91.png | RAW | RJ27CD0805 → RJ27CD0805
# OK: 910.png | SR2x+CLAHE-light | RJ14CM5701 → RJ14CM5701
# OK: 911.png | CLAHE-light | RJ34CA6992 → RJ34CA6992
# OK: 912.png | RAW | RJ14CP3701 → RJ14CP3701
# OK: 913.png | CLAHE-light | FRJ14CT7895 → RJ14CT7895
# OK: 914.png | RAW | RJ45CN1428 → RJ45CN1428
# OK: 915.png | RAW | RJ01CC8226 → RJ01CC8226
# OK: 916.png | RAW | RJ14UH5605 → RJ14UH5605
# OK: 917.png | SR2x+CLAHE-light | RJ14CT7375 → RJ14CT7375
# OK: 918.png | SR2x+CLAHE-light | RJ14CX2222 → RJ14CX2222
# OK: 919.png | SR2x+CLAHE-light | RJ45CE5167 → RJ45CE5167
# OK: 920.png | RAW | RJ14WC7009 → RJ14WC7009
# OK: 921.png | RAW | RJ14CG7995 → RJ14CG7995
# OK: 922.png | RAW | RJ27CF8975 → RJ27CF8975
# OK: 923.png | RAW | RJ44CA5682 → RJ44CA5682
# OK: 925.png | CLAHE-light | RJ14CB0709 → RJ14CB0709
# OK: 926.png | RAW | RJ14WC2831 → RJ14WC2831
# OK: 927.png | SR2x+CLAHE-light | RJ14CE4878 → RJ14CE4878
# OK: 928.png | SR2x+CLAHE-light | RJ14CH7630 → RJ14CH7630
# OK: 929.png | CLAHE-light | RJ14CT6066 → RJ14CT6066
# OK: 93.png | CLAHE-light | RJ45CJ0910 → RJ45CJ0910
# OK: 930.png | RAW | -RJ14YC1396 → RJ14YC1396
# OK: 932.png | SR2x+CLAHE-light | RJ14CQ2418 → RJ14CQ2418
# OK: 933.png | CLAHE-light | RJ45CD0869 → RJ45CD0869
# OK: 934.png | SR2x+CLAHE-light | RJ45CP9339 → RJ45CP9339
# OK: 935.png | RAW | RJ45CS5339 → RJ45CS5339
# OK: 936.png | RAW | RJ45CM8976 → RJ45CM8976
# OK: 937.png | SR2x+CLAHE-light | RJ14LC9273 → RJ14LC9273
# OK: 94.png | RAW | RJ14CW7295 → RJ14CW7295
# OK: 940.png | RAW | RJ14TE223 → RJ14TE2230
# OK: 941.png | RAW | RJ45CL7917 → RJ45CL7917
# OK: 943.png | CLAHE-light | RJ14UK3738 → RJ14UK3738
# OK: 944.png | SR2x+CLAHE-light | RJ14 CK 7225 → RJ14CK7225
# OK: 945.png | SR2x+CLAHE-light | RJ14LC9745 → RJ14LC9745
# OK: 946.png | SR2x+CLAHE-light | RJ20CF3549 → RJ20CF3549
# OK: 947.png | RAW | RJ45CS2356 → RJ45CS2356
# OK: 948.png | CLAHE-light | FRJ140C0039 → RJ14QC0039
# OK: 949.png | SR2x+CLAHE-light | RJ45C66212 → RJ45C66212
# OK: 95.png | SR2x+CLAHE-light | IND → RJ1NDO0000
# OK: 950.png | SR2x+CLAHE-light | RJ03CA0112 → RJ03CA0112
# OK: 951.png | SR2x+CLAHE-light | RJ07C86719 → RJ07CB6719
# OK: 952.png | SR2x+CLAHE-light | RJ14UG5129 → RJ14UG5129
# OK: 953.png | CLAHE-light | RJ14CP6305 → RJ14CP6305
# OK: 954.png | CLAHE-light | RJ14XC3991 → RJ14XC3991
# OK: 955.png | RAW | RJ45CT7757 → RJ45CT7757
# OK: 956.png | CLAHE-light | PRJ18CA7887 → RJ18CA7887
# OK: 957.png | SR2x+CLAHE-light | RJ14CT4486 → RJ14CT4486
# OK: 958.png | SR2x+CLAHE-light | RJ02CC3703 → RJ02CC3703
# OK: 959.png | SR2x+CLAHE-light | FRJ14VC7282 → RJ14VC7282
# OK: 96.png | SR2x+CLAHE-light | -RS14VC4705 → RJR5I4VC47
# OK: 960.png | SR2x+CLAHE-light | FRJ14NC3463 → RJ14NC3463
# OK: 961.png | RAW | RJ45CG7977 → RJ45CG7977
# OK: 962.png | RAW | RJ45CE6848 → RJ45CE6848
# OK: 963.png | RAW | RJ14CV9747 → RJ14CV9747
# OK: 964.png | SR2x+CLAHE-light | RJ45CJ8172 → RJ45CJ8172
# OK: 965.png | SR2x+CLAHE-light | RJ45CE9904 → RJ45CE9904
# OK: 966.png | SR2x+CLAHE-light | FRJ14VC9553 → RJ14VC9553
# OK: 968.png | SR2x+CLAHE-light | RJ20CB5507 → RJ20CB5507
# OK: 969.png | SR2x+CLAHE-light | RJ14CL4698 → RJ14CL4698
# OK: 97.png | CLAHE-light | RJ14CY5251 → RJ14CY5251
# OK: 970.png | SR2x+CLAHE-light | RJ14CT0511 → RJ14CT0511
# OK: 972.png | RAW | RJ14UF0093 → RJ14UF0093
# OK: 973.png | RAW | RJ14 Ch 8599 → RJ14CH8599
# OK: 974.png | RAW | RJ45C00229 → RJ45CQ0229
# OK: 975.png | RAW | RJ140C1197 → RJ14QC1197
# OK: 977.png | RAW | R.J14CX7310 → RJ14CX7310
# OK: 979.png | CLAHE-light | RJ14CK0216 → RJ14CK0216
# OK: 98.png | SR2x+CLAHE-light | RJ14UH9149 → RJ14UH9149
# OK: 980.png | CLAHE-light | RJ14CV8966 → RJ14CV8966
# OK: 981.png | SR2x+CLAHE-light | RJ45CP0711 → RJ45CP0711
# OK: 982.png | SR2x+CLAHE-light | RJ14CJ5999 → RJ14CJ5999
# OK: 983.png | SR2x+CLAHE-light | FRJ30CA9288 → RJ30CA9288
# OK: 984.png | SR2x+CLAHE-light | -RJ14TE2451 → RJ14TE2451
# OK: 985.png | SR2x+CLAHE-light | RJI4CZ3493 → RJ14CZ3493
# OK: 986.png | SR2x+CLAHE-light | FRJ14WC1332 → RJ14WC1332
# OK: 987.png | SR2x+CLAHE-light | RJ14UD9814 → RJ14UD9814
# OK: 988.png | RAW | RJ45CJ 3251 → RJ45CJ3251
# OK: 989.png | SR2x+CLAHE-light | FRJ14CV1585 → RJ14CV1585
# OK: 99.png | RAW | RJ14CU4226 → RJ14CU4226
# OK: 990.png | SR2x+CLAHE-light | RJ14CD7590 → RJ14CD7590
# OK: 992.png | RAW | RJ45CG0374 → RJ45CG0374
# OK: 993.png | RAW | RJ14CY3589 → RJ14CY3589
# OK: 994.png | SR2x+CLAHE-light | RJ45CK5666 → RJ45CK5666
# OK: 995.png | RAW | RJ45CF2591 → RJ45CF2591
# OK: 996.png | SR2x+CLAHE-light | RJ45CM6777 → RJ45CM6777
# OK: 997.png | SR2x+CLAHE-light | RJ07CD4085 → RJ07CD4085
# OK: 998.png | RAW | RJ36CA7025 → RJ36CA7025
# OK: 999.png | RAW | RJ140C5325 → RJ14QC5325
# DONE. Saved: hasil_adaptive_initial.csv

# %% [markdown]
# #EVALUATION (NO NUMPY) - ADAPTIVE (INITIAL)#

# %%
import csv, re

# ------------------------------------------------------
# 1) Same helpers as pipeline
# ------------------------------------------------------
def clean_raw(text):
    return re.sub(r"[^A-Z0-9]", "", str(text).upper())

def normalize_rj_fixedpos(raw_text):
    """
    HARUS sama dengan normalize_rj_fixedpos() di script Adaptive (initial).
    (anchor RJ + enforce length 10 + casting digit/alpha + pair fix QC/CQ)
    """
    t0 = clean_raw(raw_text)

    if "RJ" in t0:
        t = t0[t0.find("RJ"):]
    else:
        t = "RJ" + t0

    if len(t) < 10:
        t = t.ljust(10, "0")
    else:
        t = t[:10]

    chars = list(t)
    chars[0], chars[1] = "R", "J"

    DIGIT_IDX = {2, 3, 6, 7, 8, 9}
    ALPHA_IDX = {4, 5}
    TO_DIGIT = {'O': '0', 'Q': '0', 'D': '0', 'I': '1', 'L': '1', 'Z': '2', 'S': '5', 'B': '8'}
    TO_ALPHA = {'0': 'O', '1': 'I', '2': 'Z', '5': 'S', '8': 'B'}

    for i in range(10):
        if i in DIGIT_IDX and chars[i] in TO_DIGIT:
            chars[i] = TO_DIGIT[chars[i]]
        elif i in ALPHA_IDX and chars[i] in TO_ALPHA:
            chars[i] = TO_ALPHA[chars[i]]

    # pair fix [4-5]
    pair = chars[4] + chars[5]
    pair_map = {"OC": ("Q", "C"), "CO": ("C", "Q"), "0C": ("Q", "C"), "C0": ("C", "Q")}
    if pair in pair_map:
        chars[4], chars[5] = pair_map[pair]

    return "".join(chars)

def levenshtein(a, b):
    if a == b: return 0
    if not a: return len(b)
    if not b: return len(a)
    prev = list(range(len(b)+1))
    for i, ca in enumerate(a, 1):
        cur = [i]
        for j, cb in enumerate(b, 1):
            cur.append(min(cur[j-1]+1, prev[j]+1, prev[j-1]+(ca!=cb)))
        prev = cur
    return prev[-1]

# ------------------------------------------------------
# 2) Load Ground Truth
#    GT format: "filename<TAB>plate"
# ------------------------------------------------------
GT_PATH = r"ground truth.txt"  # <-- ganti jika perlu
gt = {}
with open(GT_PATH, "r", encoding="utf-8", errors="ignore") as f:
    for line in f:
        line = line.strip()
        if not line or "\t" not in line:
            continue
        img, plate = line.split("\t", 1)
        fname = img.split("/")[-1].split("\\")[-1]
        gt[fname] = normalize_rj_fixedpos(plate)

# ------------------------------------------------------
# 3) Load CSV Adaptive (initial)
#    CSV columns from script: File_Name, Variant, Raw_OCR, Final_Text, Conf_0to1
# ------------------------------------------------------
CSV_PATH = r"result_adaptive_initial.csv"  # <-- CSV hasil Adaptive (initial)
with open(CSV_PATH, newline="", encoding="utf-8", errors="replace") as f:
    rows = list(csv.DictReader(f))

# ------------------------------------------------------
# 4) Evaluation Metrics
#    - Readability: raw OCR not empty and conf > 0
#    - Exact Accuracy: pred == GT (normalized to fixed 10)
#    - Character Accuracy: 1 - Levenshtein/10
# ------------------------------------------------------
total = 0
unreadable = 0
readable = 0

correct_e2e = 0       # exact / total
recog_total = 0       # readable count
recog_correct = 0     # exact among readable
char_sum = 0.0        # avg char acc among readable

for r in rows:
    fname = (r.get("File_Name") or "").strip()
    if not fname or fname not in gt:
        continue

    total += 1

    raw = (r.get("Raw_OCR") or "").strip()
    conf_raw = (r.get("Conf_0to1") or "").strip()
    try:
        conf = float(conf_raw)
    except:
        conf = 1.0 if raw != "" else 0.0

    # Readability criterion (selaras dengan pipeline)
    if raw == "" or conf <= 0.0:
        unreadable += 1
        continue

    readable += 1
    recog_total += 1

    # pred di CSV sudah Final_Text (dari pipeline)
    pred_csv = (r.get("Final_Text") or "").strip()

    # Untuk aman: normalize lagi ke fixed 10 (selaras GT)
    pred = normalize_rj_fixedpos(pred_csv)
    gt_plate = gt[fname]

    if pred == gt_plate:
        recog_correct += 1
        correct_e2e += 1

    dist = levenshtein(pred, gt_plate)
    char_sum += (1 - dist/10.0)

# ------------------------------------------------------
# 5) Print Results
# ------------------------------------------------------
print("\n=== EVALUATION RESULT (ADAPTIVE INITIAL) ===")
print("Total samples       :", total)
print("Unreadable (OCR=∅)  :", unreadable)
print("Readable            :", readable)
print("----------------------------------")

if total > 0:
    print(f"Readability Rate          : {readable/total*100:.2f}%")
    print(f"End-to-End Exact Accuracy : {correct_e2e/total*100:.2f}%")
else:
    print("Readability Rate          : 0.00%")
    print("End-to-End Exact Accuracy : 0.00%")

if recog_total:
    print(f"Recognition Exact Acc     : {recog_correct/recog_total*100:.2f}%")
    print(f"Average Character Acc     : {char_sum/recog_total*100:.2f}%")
else:
    print("Recognition Exact Acc     : 0.00%")
    print("Average Character Acc     : 0.00%")
# Out:
# === EVALUATION RESULT (ADAPTIVE INITIAL) ===
# Total samples       : 750
# Unreadable (OCR=∅)  : 0
# Readable            : 750
# ----------------------------------
# Readability Rate          : 100.00%
# End-to-End Exact Accuracy : 90.93%
# Recognition Exact Acc     : 90.93%
# Average Character Acc     : 97.04%
